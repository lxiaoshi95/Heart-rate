# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
import pywt
import timeit
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn import metrics, preprocessing
from scipy import signal
from keras.layers import Dense, Flatten, Activation, TimeDistributed
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import AveragePooling1D
from keras.layers import GlobalMaxPooling1D
from keras.layers import GlobalAveragePooling1D
from keras.utils import np_utils
from keras.optimizers import SGD, Adam, Nadam
from keras.callbacks import ModelCheckpoint
from keras.layers.normalization import BatchNormalization
import keras.callbacks
from keras import initializers, regularizers
from keras.layers.pooling import GlobalAvgPool2D
from keras.layers.recurrent import LSTM
from keras.layers.advanced_activations import LeakyReLU, PReLU
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(42)
dataset = sio.loadmat('dataset_1.mat')
heart_rate = dataset['heart_rate']
heart_rate = (heart_rate - 50) / 150
ss = np.zeros((3203, 1000, 1))
signal = dataset['signal']
ss[:, :, 0] = signal
print(ss.shape)
print(heart_rate.shape)
# Out:
# (3203, 1000, 1)
# (3203, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(ss, heart_rate, test_size=0.2, random_state=123)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (2562, 1000, 1)
# (641, 1000, 1)
# (2562, 1)
# (641, 1)

# %%
# network design
model = Sequential()
# first part
model.add(Conv1D(64, 16, padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
# second part
model.add(Conv1D(64, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(64, 16, padding='same'))
model.add(MaxPooling1D())
# third layers
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(64, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(64, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(128, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(128, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(128, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(128, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(192, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(192, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(192, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(192, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(256, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(256, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(256, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(256, 16, padding='same'))
model.add(MaxPooling1D())
##
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(Flatten())
model.add(LSTM(units=256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1, activation='sigmoid'))

#model.summary()

# %%
# optimization setup
optm = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=3*10**(-4))
sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
model.compile(
    loss='mae',
    optimizer=optm,
    metrics=['mse'])

# %%
filepath="weights.best1.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_mean_squared_error', mode='auto', verbose=1, save_best_only=True)
callbacks_list = [checkpoint]

# %%
# training
model.fit(
    X_train, 
    Y_train,
    batch_size=128,
    epochs=3000,
    validation_split=0.2,
    shuffle=True,
    callbacks=callbacks_list,
    verbose=2)
# Out:
# Train on 2049 samples, validate on 513 samples
# Epoch 1/3000
#  - 8s - loss: 0.1621 - mean_squared_error: 0.0389 - val_loss: 0.1577 - val_mean_squared_error: 0.0361
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.03610, saving model to weights.best1.hdf5
# Epoch 2/3000
#  - 2s - loss: 0.1610 - mean_squared_error: 0.0378 - val_loss: 0.1553 - val_mean_squared_error: 0.0354
#
# Epoch 00002: val_mean_squared_error improved from 0.03610 to 0.03536, saving model to weights.best1.hdf5
# Epoch 3/3000
#  - 2s - loss: 0.1605 - mean_squared_error: 0.0393 - val_loss: 0.1508 - val_mean_squared_error: 0.0344
#
# Epoch 00003: val_mean_squared_error improved from 0.03536 to 0.03444, saving model to weights.best1.hdf5
# Epoch 4/3000
#  - 2s - loss: 0.1601 - mean_squared_error: 0.0385 - val_loss: 0.1497 - val_mean_squared_error: 0.0340
#
# Epoch 00004: val_mean_squared_error improved from 0.03444 to 0.03396, saving model to weights.best1.hdf5
# Epoch 5/3000
#  - 2s - loss: 0.1590 - mean_squared_error: 0.0368 - val_loss: 0.1516 - val_mean_squared_error: 0.0341
#
# Epoch 00005: val_mean_squared_error did not improve from 0.03396
# Epoch 6/3000
#  - 2s - loss: 0.1563 - mean_squared_error: 0.0387 - val_loss: 0.1534 - val_mean_squared_error: 0.0345
#
# Epoch 00006: val_mean_squared_error did not improve from 0.03396
# Epoch 7/3000
#  - 2s - loss: 0.1475 - mean_squared_error: 0.0331 - val_loss: 0.1687 - val_mean_squared_error: 0.0385
#
# Epoch 00007: val_mean_squared_error did not improve from 0.03396
# Epoch 8/3000
#  - 2s - loss: 0.1345 - mean_squared_error: 0.0296 - val_loss: 0.1995 - val_mean_squared_error: 0.0509
#
# Epoch 00008: val_mean_squared_error did not improve from 0.03396
# Epoch 9/3000
#  - 2s - loss: 0.1176 - mean_squared_error: 0.0237 - val_loss: 0.2436 - val_mean_squared_error: 0.0831
#
# Epoch 00009: val_mean_squared_error did not improve from 0.03396
# Epoch 10/3000
#  - 2s - loss: 0.1078 - mean_squared_error: 0.0214 - val_loss: 0.3337 - val_mean_squared_error: 0.1413
#
# Epoch 00010: val_mean_squared_error did not improve from 0.03396
# Epoch 11/3000
#  - 2s - loss: 0.1000 - mean_squared_error: 0.0196 - val_loss: 0.2645 - val_mean_squared_error: 0.1004
#
# Epoch 00011: val_mean_squared_error did not improve from 0.03396
# Epoch 12/3000
#  - 2s - loss: 0.0914 - mean_squared_error: 0.0173 - val_loss: 0.2199 - val_mean_squared_error: 0.0828
#
# Epoch 00012: val_mean_squared_error did not improve from 0.03396
# Epoch 13/3000
#  - 2s - loss: 0.0856 - mean_squared_error: 0.0159 - val_loss: 0.3326 - val_mean_squared_error: 0.1455
#
# Epoch 00013: val_mean_squared_error did not improve from 0.03396
# Epoch 14/3000
#  - 2s - loss: 0.0818 - mean_squared_error: 0.0145 - val_loss: 0.1805 - val_mean_squared_error: 0.0596
#
# Epoch 00014: val_mean_squared_error did not improve from 0.03396
# Epoch 15/3000
#  - 2s - loss: 0.0801 - mean_squared_error: 0.0148 - val_loss: 0.2619 - val_mean_squared_error: 0.1071
#
# Epoch 00015: val_mean_squared_error did not improve from 0.03396
# Epoch 16/3000
#  - 2s - loss: 0.0766 - mean_squared_error: 0.0142 - val_loss: 0.1782 - val_mean_squared_error: 0.0619
#
# Epoch 00016: val_mean_squared_error did not improve from 0.03396
# Epoch 17/3000
#  - 2s - loss: 0.0761 - mean_squared_error: 0.0146 - val_loss: 0.1144 - val_mean_squared_error: 0.0341
#
# Epoch 00017: val_mean_squared_error did not improve from 0.03396
# Epoch 18/3000
#  - 2s - loss: 0.0685 - mean_squared_error: 0.0127 - val_loss: 0.1627 - val_mean_squared_error: 0.0539
#
# Epoch 00018: val_mean_squared_error did not improve from 0.03396
# Epoch 19/3000
#  - 2s - loss: 0.0711 - mean_squared_error: 0.0135 - val_loss: 0.1072 - val_mean_squared_error: 0.0330
#
# Epoch 00019: val_mean_squared_error improved from 0.03396 to 0.03303, saving model to weights.best1.hdf5
# Epoch 20/3000
#  - 2s - loss: 0.0642 - mean_squared_error: 0.0117 - val_loss: 0.1118 - val_mean_squared_error: 0.0353
#
# Epoch 00020: val_mean_squared_error did not improve from 0.03303
# Epoch 21/3000
#  - 2s - loss: 0.0611 - mean_squared_error: 0.0111 - val_loss: 0.0976 - val_mean_squared_error: 0.0276
#
# Epoch 00021: val_mean_squared_error improved from 0.03303 to 0.02758, saving model to weights.best1.hdf5
# Epoch 22/3000
#  - 2s - loss: 0.0570 - mean_squared_error: 0.0097 - val_loss: 0.0782 - val_mean_squared_error: 0.0184
#
# Epoch 00022: val_mean_squared_error improved from 0.02758 to 0.01837, saving model to weights.best1.hdf5
# Epoch 23/3000
#  - 2s - loss: 0.0603 - mean_squared_error: 0.0110 - val_loss: 0.0736 - val_mean_squared_error: 0.0182
#
# Epoch 00023: val_mean_squared_error improved from 0.01837 to 0.01816, saving model to weights.best1.hdf5
# Epoch 24/3000
#  - 2s - loss: 0.0570 - mean_squared_error: 0.0100 - val_loss: 0.0794 - val_mean_squared_error: 0.0182
#
# Epoch 00024: val_mean_squared_error did not improve from 0.01816
# Epoch 25/3000
#  - 2s - loss: 0.0546 - mean_squared_error: 0.0091 - val_loss: 0.0661 - val_mean_squared_error: 0.0114
#
# Epoch 00025: val_mean_squared_error improved from 0.01816 to 0.01141, saving model to weights.best1.hdf5
# Epoch 26/3000
#  - 2s - loss: 0.0575 - mean_squared_error: 0.0103 - val_loss: 0.0764 - val_mean_squared_error: 0.0145
#
# Epoch 00026: val_mean_squared_error did not improve from 0.01141
# Epoch 27/3000
#  - 2s - loss: 0.0531 - mean_squared_error: 0.0081 - val_loss: 0.0559 - val_mean_squared_error: 0.0094
#
# Epoch 00027: val_mean_squared_error improved from 0.01141 to 0.00944, saving model to weights.best1.hdf5
# Epoch 28/3000
#  - 2s - loss: 0.0516 - mean_squared_error: 0.0081 - val_loss: 0.0589 - val_mean_squared_error: 0.0122
#
# Epoch 00028: val_mean_squared_error did not improve from 0.00944
# Epoch 29/3000
#  - 2s - loss: 0.0457 - mean_squared_error: 0.0061 - val_loss: 0.0499 - val_mean_squared_error: 0.0069
#
# Epoch 00029: val_mean_squared_error improved from 0.00944 to 0.00691, saving model to weights.best1.hdf5
# Epoch 30/3000
#  - 2s - loss: 0.0433 - mean_squared_error: 0.0055 - val_loss: 0.0597 - val_mean_squared_error: 0.0106
#
# Epoch 00030: val_mean_squared_error did not improve from 0.00691
# Epoch 31/3000
#  - 2s - loss: 0.0455 - mean_squared_error: 0.0072 - val_loss: 0.0449 - val_mean_squared_error: 0.0065
#
# Epoch 00031: val_mean_squared_error improved from 0.00691 to 0.00653, saving model to weights.best1.hdf5
# Epoch 32/3000
#  - 2s - loss: 0.0427 - mean_squared_error: 0.0060 - val_loss: 0.0540 - val_mean_squared_error: 0.0085
#
# Epoch 00032: val_mean_squared_error did not improve from 0.00653
# Epoch 33/3000
#  - 2s - loss: 0.0427 - mean_squared_error: 0.0061 - val_loss: 0.0596 - val_mean_squared_error: 0.0121
#
# Epoch 00033: val_mean_squared_error did not improve from 0.00653
# Epoch 34/3000
#  - 2s - loss: 0.0424 - mean_squared_error: 0.0060 - val_loss: 0.0537 - val_mean_squared_error: 0.0113
#
# Epoch 00034: val_mean_squared_error did not improve from 0.00653
# Epoch 35/3000
#  - 2s - loss: 0.0406 - mean_squared_error: 0.0052 - val_loss: 0.0605 - val_mean_squared_error: 0.0145
#
# Epoch 00035: val_mean_squared_error did not improve from 0.00653
# Epoch 36/3000
#  - 2s - loss: 0.0410 - mean_squared_error: 0.0057 - val_loss: 0.0530 - val_mean_squared_error: 0.0098
#
# Epoch 00036: val_mean_squared_error did not improve from 0.00653
# Epoch 37/3000
#  - 2s - loss: 0.0394 - mean_squared_error: 0.0044 - val_loss: 0.0552 - val_mean_squared_error: 0.0127
#
# Epoch 00037: val_mean_squared_error did not improve from 0.00653
# Epoch 38/3000
#  - 2s - loss: 0.0407 - mean_squared_error: 0.0057 - val_loss: 0.0626 - val_mean_squared_error: 0.0139
#
# Epoch 00038: val_mean_squared_error did not improve from 0.00653
# Epoch 39/3000
#  - 2s - loss: 0.0398 - mean_squared_error: 0.0051 - val_loss: 0.0633 - val_mean_squared_error: 0.0134
#
# Epoch 00039: val_mean_squared_error did not improve from 0.00653
# Epoch 40/3000
#  - 2s - loss: 0.0367 - mean_squared_error: 0.0046 - val_loss: 0.0853 - val_mean_squared_error: 0.0215
#
# Epoch 00040: val_mean_squared_error did not improve from 0.00653
# Epoch 41/3000
#  - 2s - loss: 0.0365 - mean_squared_error: 0.0048 - val_loss: 0.0549 - val_mean_squared_error: 0.0105
#
# Epoch 00041: val_mean_squared_error did not improve from 0.00653
# Epoch 42/3000
#  - 2s - loss: 0.0361 - mean_squared_error: 0.0048 - val_loss: 0.0474 - val_mean_squared_error: 0.0089
#
# Epoch 00042: val_mean_squared_error did not improve from 0.00653
# Epoch 43/3000
#  - 2s - loss: 0.0349 - mean_squared_error: 0.0042 - val_loss: 0.0529 - val_mean_squared_error: 0.0091
#
# Epoch 00043: val_mean_squared_error did not improve from 0.00653
# Epoch 44/3000
#  - 2s - loss: 0.0342 - mean_squared_error: 0.0036 - val_loss: 0.0379 - val_mean_squared_error: 0.0059
#
# Epoch 00044: val_mean_squared_error improved from 0.00653 to 0.00595, saving model to weights.best1.hdf5
# Epoch 45/3000
#  - 2s - loss: 0.0332 - mean_squared_error: 0.0036 - val_loss: 0.0486 - val_mean_squared_error: 0.0081
#
# Epoch 00045: val_mean_squared_error did not improve from 0.00595
# Epoch 46/3000
#  - 2s - loss: 0.0343 - mean_squared_error: 0.0037 - val_loss: 0.0565 - val_mean_squared_error: 0.0102
#
# Epoch 00046: val_mean_squared_error did not improve from 0.00595
# Epoch 47/3000
#  - 2s - loss: 0.0319 - mean_squared_error: 0.0031 - val_loss: 0.0433 - val_mean_squared_error: 0.0082
#
# Epoch 00047: val_mean_squared_error did not improve from 0.00595
# Epoch 48/3000
#  - 2s - loss: 0.0302 - mean_squared_error: 0.0031 - val_loss: 0.0417 - val_mean_squared_error: 0.0078
#
# Epoch 00048: val_mean_squared_error did not improve from 0.00595
# Epoch 49/3000
#  - 2s - loss: 0.0291 - mean_squared_error: 0.0027 - val_loss: 0.0486 - val_mean_squared_error: 0.0079
#
# Epoch 00049: val_mean_squared_error did not improve from 0.00595
# Epoch 50/3000
#  - 2s - loss: 0.0329 - mean_squared_error: 0.0044 - val_loss: 0.0963 - val_mean_squared_error: 0.0281
#
# Epoch 00050: val_mean_squared_error did not improve from 0.00595
# Epoch 51/3000
#  - 2s - loss: 0.0322 - mean_squared_error: 0.0036 - val_loss: 0.0986 - val_mean_squared_error: 0.0320
#
# Epoch 00051: val_mean_squared_error did not improve from 0.00595
# Epoch 52/3000
#  - 2s - loss: 0.0293 - mean_squared_error: 0.0031 - val_loss: 0.0636 - val_mean_squared_error: 0.0145
#
# Epoch 00052: val_mean_squared_error did not improve from 0.00595
# Epoch 53/3000
#  - 2s - loss: 0.0296 - mean_squared_error: 0.0030 - val_loss: 0.0383 - val_mean_squared_error: 0.0071
#
# Epoch 00053: val_mean_squared_error did not improve from 0.00595
# Epoch 54/3000
#  - 2s - loss: 0.0281 - mean_squared_error: 0.0021 - val_loss: 0.0355 - val_mean_squared_error: 0.0050
#
# Epoch 00054: val_mean_squared_error improved from 0.00595 to 0.00497, saving model to weights.best1.hdf5
# Epoch 55/3000
#  - 2s - loss: 0.0286 - mean_squared_error: 0.0030 - val_loss: 0.0339 - val_mean_squared_error: 0.0047
#
# Epoch 00055: val_mean_squared_error improved from 0.00497 to 0.00470, saving model to weights.best1.hdf5
# Epoch 56/3000
#  - 2s - loss: 0.0289 - mean_squared_error: 0.0030 - val_loss: 0.0447 - val_mean_squared_error: 0.0084
#
# Epoch 00056: val_mean_squared_error did not improve from 0.00470
# Epoch 57/3000
#  - 2s - loss: 0.0284 - mean_squared_error: 0.0024 - val_loss: 0.0612 - val_mean_squared_error: 0.0114
#
# Epoch 00057: val_mean_squared_error did not improve from 0.00470
# Epoch 58/3000
#  - 2s - loss: 0.0304 - mean_squared_error: 0.0035 - val_loss: 0.0441 - val_mean_squared_error: 0.0094
#
# Epoch 00058: val_mean_squared_error did not improve from 0.00470
# Epoch 59/3000
#  - 2s - loss: 0.0300 - mean_squared_error: 0.0031 - val_loss: 0.0712 - val_mean_squared_error: 0.0194
#
# Epoch 00059: val_mean_squared_error did not improve from 0.00470
# Epoch 60/3000
#  - 2s - loss: 0.0242 - mean_squared_error: 0.0019 - val_loss: 0.0889 - val_mean_squared_error: 0.0264
#
# Epoch 00060: val_mean_squared_error did not improve from 0.00470
# Epoch 61/3000
#  - 2s - loss: 0.0303 - mean_squared_error: 0.0043 - val_loss: 0.0761 - val_mean_squared_error: 0.0219
#
# Epoch 00061: val_mean_squared_error did not improve from 0.00470
# Epoch 62/3000
#  - 2s - loss: 0.0269 - mean_squared_error: 0.0022 - val_loss: 0.0641 - val_mean_squared_error: 0.0164
#
# Epoch 00062: val_mean_squared_error did not improve from 0.00470
# Epoch 63/3000
#  - 2s - loss: 0.0251 - mean_squared_error: 0.0017 - val_loss: 0.0466 - val_mean_squared_error: 0.0095
#
# Epoch 00063: val_mean_squared_error did not improve from 0.00470
# Epoch 64/3000
#  - 2s - loss: 0.0238 - mean_squared_error: 0.0017 - val_loss: 0.0367 - val_mean_squared_error: 0.0064
#
# Epoch 00064: val_mean_squared_error did not improve from 0.00470
# Epoch 65/3000
#  - 2s - loss: 0.0230 - mean_squared_error: 0.0015 - val_loss: 0.0356 - val_mean_squared_error: 0.0051
#
# Epoch 00065: val_mean_squared_error did not improve from 0.00470
# Epoch 66/3000
#  - 2s - loss: 0.0228 - mean_squared_error: 0.0018 - val_loss: 0.0349 - val_mean_squared_error: 0.0062
#
# Epoch 00066: val_mean_squared_error did not improve from 0.00470
# Epoch 67/3000
#  - 2s - loss: 0.0233 - mean_squared_error: 0.0017 - val_loss: 0.0460 - val_mean_squared_error: 0.0100
#
# Epoch 00067: val_mean_squared_error did not improve from 0.00470
# Epoch 68/3000
#  - 2s - loss: 0.0232 - mean_squared_error: 0.0017 - val_loss: 0.0441 - val_mean_squared_error: 0.0090
#
# Epoch 00068: val_mean_squared_error did not improve from 0.00470
# Epoch 69/3000
#  - 2s - loss: 0.0239 - mean_squared_error: 0.0020 - val_loss: 0.0341 - val_mean_squared_error: 0.0050
#
# Epoch 00069: val_mean_squared_error did not improve from 0.00470
# Epoch 70/3000
#  - 2s - loss: 0.0233 - mean_squared_error: 0.0017 - val_loss: 0.0500 - val_mean_squared_error: 0.0123
#
# Epoch 00070: val_mean_squared_error did not improve from 0.00470
# Epoch 71/3000
#  - 2s - loss: 0.0237 - mean_squared_error: 0.0015 - val_loss: 0.0310 - val_mean_squared_error: 0.0043
#
# Epoch 00071: val_mean_squared_error improved from 0.00470 to 0.00430, saving model to weights.best1.hdf5
# Epoch 72/3000
#  - 2s - loss: 0.0237 - mean_squared_error: 0.0020 - val_loss: 0.0389 - val_mean_squared_error: 0.0090
#
# Epoch 00072: val_mean_squared_error did not improve from 0.00430
# Epoch 73/3000
#  - 2s - loss: 0.0206 - mean_squared_error: 0.0013 - val_loss: 0.0487 - val_mean_squared_error: 0.0112
#
# Epoch 00073: val_mean_squared_error did not improve from 0.00430
# Epoch 74/3000
#  - 2s - loss: 0.0214 - mean_squared_error: 0.0012 - val_loss: 0.0311 - val_mean_squared_error: 0.0046
#
# Epoch 00074: val_mean_squared_error did not improve from 0.00430
# Epoch 75/3000
#  - 2s - loss: 0.0205 - mean_squared_error: 0.0011 - val_loss: 0.0292 - val_mean_squared_error: 0.0034
#
# Epoch 00075: val_mean_squared_error improved from 0.00430 to 0.00339, saving model to weights.best1.hdf5
# Epoch 76/3000
#  - 2s - loss: 0.0207 - mean_squared_error: 0.0011 - val_loss: 0.0289 - val_mean_squared_error: 0.0032
#
# Epoch 00076: val_mean_squared_error improved from 0.00339 to 0.00324, saving model to weights.best1.hdf5
# Epoch 77/3000
#  - 2s - loss: 0.0199 - mean_squared_error: 9.9058e-04 - val_loss: 0.0275 - val_mean_squared_error: 0.0031
#
# Epoch 00077: val_mean_squared_error improved from 0.00324 to 0.00308, saving model to weights.best1.hdf5
# Epoch 78/3000
#  - 2s - loss: 0.0203 - mean_squared_error: 0.0013 - val_loss: 0.0351 - val_mean_squared_error: 0.0061
#
# Epoch 00078: val_mean_squared_error did not improve from 0.00308
# Epoch 79/3000
#  - 2s - loss: 0.0199 - mean_squared_error: 0.0011 - val_loss: 0.0219 - val_mean_squared_error: 0.0029
#
# Epoch 00079: val_mean_squared_error improved from 0.00308 to 0.00290, saving model to weights.best1.hdf5
# Epoch 80/3000
#  - 2s - loss: 0.0215 - mean_squared_error: 0.0014 - val_loss: 0.0259 - val_mean_squared_error: 0.0028
#
# Epoch 00080: val_mean_squared_error improved from 0.00290 to 0.00276, saving model to weights.best1.hdf5
# Epoch 81/3000
#  - 2s - loss: 0.0193 - mean_squared_error: 0.0010 - val_loss: 0.0270 - val_mean_squared_error: 0.0040
#
# Epoch 00081: val_mean_squared_error did not improve from 0.00276
# Epoch 82/3000
#  - 2s - loss: 0.0175 - mean_squared_error: 8.4545e-04 - val_loss: 0.0238 - val_mean_squared_error: 0.0023
#
# Epoch 00082: val_mean_squared_error improved from 0.00276 to 0.00226, saving model to weights.best1.hdf5
# Epoch 83/3000
#  - 2s - loss: 0.0193 - mean_squared_error: 0.0010 - val_loss: 0.0316 - val_mean_squared_error: 0.0048
#
# Epoch 00083: val_mean_squared_error did not improve from 0.00226
# Epoch 84/3000
#  - 2s - loss: 0.0188 - mean_squared_error: 8.6483e-04 - val_loss: 0.0398 - val_mean_squared_error: 0.0079
#
# Epoch 00084: val_mean_squared_error did not improve from 0.00226
# Epoch 85/3000
#  - 2s - loss: 0.0180 - mean_squared_error: 8.9044e-04 - val_loss: 0.0269 - val_mean_squared_error: 0.0034
#
# Epoch 00085: val_mean_squared_error did not improve from 0.00226
# Epoch 86/3000
#  - 2s - loss: 0.0209 - mean_squared_error: 0.0015 - val_loss: 0.0578 - val_mean_squared_error: 0.0134
#
# Epoch 00086: val_mean_squared_error did not improve from 0.00226
# Epoch 87/3000
#  - 2s - loss: 0.0202 - mean_squared_error: 0.0013 - val_loss: 0.0239 - val_mean_squared_error: 0.0029
#
# Epoch 00087: val_mean_squared_error did not improve from 0.00226
# Epoch 88/3000
#  - 2s - loss: 0.0200 - mean_squared_error: 0.0012 - val_loss: 0.0215 - val_mean_squared_error: 0.0025
#
# Epoch 00088: val_mean_squared_error did not improve from 0.00226
# Epoch 89/3000
#  - 2s - loss: 0.0197 - mean_squared_error: 0.0011 - val_loss: 0.0301 - val_mean_squared_error: 0.0053
#
# Epoch 00089: val_mean_squared_error did not improve from 0.00226
# Epoch 90/3000
#  - 2s - loss: 0.0183 - mean_squared_error: 8.7583e-04 - val_loss: 0.0281 - val_mean_squared_error: 0.0046
#
# Epoch 00090: val_mean_squared_error did not improve from 0.00226
# Epoch 91/3000
#  - 2s - loss: 0.0176 - mean_squared_error: 8.3514e-04 - val_loss: 0.0342 - val_mean_squared_error: 0.0072
#
# Epoch 00091: val_mean_squared_error did not improve from 0.00226
# Epoch 92/3000
#  - 2s - loss: 0.0185 - mean_squared_error: 0.0010 - val_loss: 0.0228 - val_mean_squared_error: 0.0021
#
# Epoch 00092: val_mean_squared_error improved from 0.00226 to 0.00208, saving model to weights.best1.hdf5
# Epoch 93/3000
#  - 2s - loss: 0.0191 - mean_squared_error: 0.0014 - val_loss: 0.0333 - val_mean_squared_error: 0.0063
#
# Epoch 00093: val_mean_squared_error did not improve from 0.00208
# Epoch 94/3000
#  - 2s - loss: 0.0217 - mean_squared_error: 0.0020 - val_loss: 0.0357 - val_mean_squared_error: 0.0069
#
# Epoch 00094: val_mean_squared_error did not improve from 0.00208
# Epoch 95/3000
#  - 2s - loss: 0.0235 - mean_squared_error: 0.0025 - val_loss: 0.0307 - val_mean_squared_error: 0.0042
#
# Epoch 00095: val_mean_squared_error did not improve from 0.00208
# Epoch 96/3000
#  - 2s - loss: 0.0234 - mean_squared_error: 0.0024 - val_loss: 0.0337 - val_mean_squared_error: 0.0054
#
# Epoch 00096: val_mean_squared_error did not improve from 0.00208
# Epoch 97/3000
#  - 2s - loss: 0.0211 - mean_squared_error: 0.0019 - val_loss: 0.0225 - val_mean_squared_error: 0.0030
#
# Epoch 00097: val_mean_squared_error did not improve from 0.00208
# Epoch 98/3000
#  - 2s - loss: 0.0194 - mean_squared_error: 0.0015 - val_loss: 0.0228 - val_mean_squared_error: 0.0019
#
# Epoch 00098: val_mean_squared_error improved from 0.00208 to 0.00188, saving model to weights.best1.hdf5
# Epoch 99/3000
#  - 2s - loss: 0.0207 - mean_squared_error: 0.0022 - val_loss: 0.0324 - val_mean_squared_error: 0.0063
#
# Epoch 00099: val_mean_squared_error did not improve from 0.00188
# Epoch 100/3000
#  - 2s - loss: 0.0199 - mean_squared_error: 0.0015 - val_loss: 0.0312 - val_mean_squared_error: 0.0047
#
# Epoch 00100: val_mean_squared_error did not improve from 0.00188
# Epoch 101/3000
#  - 2s - loss: 0.0174 - mean_squared_error: 8.7117e-04 - val_loss: 0.0239 - val_mean_squared_error: 0.0032
#
# Epoch 00101: val_mean_squared_error did not improve from 0.00188
# Epoch 102/3000
#  - 2s - loss: 0.0167 - mean_squared_error: 6.6063e-04 - val_loss: 0.0215 - val_mean_squared_error: 0.0030
#
# Epoch 00102: val_mean_squared_error did not improve from 0.00188
# Epoch 103/3000
#  - 2s - loss: 0.0163 - mean_squared_error: 6.4261e-04 - val_loss: 0.0223 - val_mean_squared_error: 0.0032
#
# Epoch 00103: val_mean_squared_error did not improve from 0.00188
# Epoch 104/3000
#  - 2s - loss: 0.0164 - mean_squared_error: 6.2760e-04 - val_loss: 0.0249 - val_mean_squared_error: 0.0039
#
# Epoch 00104: val_mean_squared_error did not improve from 0.00188
# Epoch 105/3000
#  - 2s - loss: 0.0182 - mean_squared_error: 0.0012 - val_loss: 0.0214 - val_mean_squared_error: 0.0024
#
# Epoch 00105: val_mean_squared_error did not improve from 0.00188
# Epoch 106/3000
#  - 2s - loss: 0.0184 - mean_squared_error: 0.0013 - val_loss: 0.0536 - val_mean_squared_error: 0.0149
#
# Epoch 00106: val_mean_squared_error did not improve from 0.00188
# Epoch 107/3000
#  - 2s - loss: 0.0194 - mean_squared_error: 0.0012 - val_loss: 0.0606 - val_mean_squared_error: 0.0188
#
# Epoch 00107: val_mean_squared_error did not improve from 0.00188
# Epoch 108/3000
#  - 2s - loss: 0.0195 - mean_squared_error: 0.0013 - val_loss: 0.0264 - val_mean_squared_error: 0.0043
#
# Epoch 00108: val_mean_squared_error did not improve from 0.00188
# Epoch 109/3000
#  - 2s - loss: 0.0168 - mean_squared_error: 6.8887e-04 - val_loss: 0.0334 - val_mean_squared_error: 0.0084
#
# Epoch 00109: val_mean_squared_error did not improve from 0.00188
# Epoch 110/3000
#  - 2s - loss: 0.0171 - mean_squared_error: 8.3086e-04 - val_loss: 0.0209 - val_mean_squared_error: 0.0026
#
# Epoch 00110: val_mean_squared_error did not improve from 0.00188
# Epoch 111/3000
#  - 2s - loss: 0.0176 - mean_squared_error: 8.3201e-04 - val_loss: 0.0217 - val_mean_squared_error: 0.0022
#
# Epoch 00111: val_mean_squared_error did not improve from 0.00188
# Epoch 112/3000
#  - 2s - loss: 0.0167 - mean_squared_error: 8.4545e-04 - val_loss: 0.0218 - val_mean_squared_error: 0.0030
#
# Epoch 00112: val_mean_squared_error did not improve from 0.00188
# Epoch 113/3000
#  - 2s - loss: 0.0167 - mean_squared_error: 7.2465e-04 - val_loss: 0.0218 - val_mean_squared_error: 0.0022
#
# Epoch 00113: val_mean_squared_error did not improve from 0.00188
# Epoch 114/3000
#  - 2s - loss: 0.0173 - mean_squared_error: 7.8173e-04 - val_loss: 0.0235 - val_mean_squared_error: 0.0026
#
# Epoch 00114: val_mean_squared_error did not improve from 0.00188
# Epoch 115/3000
#  - 2s - loss: 0.0178 - mean_squared_error: 9.1383e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0013
#
# Epoch 00115: val_mean_squared_error improved from 0.00188 to 0.00126, saving model to weights.best1.hdf5
# Epoch 116/3000
#  - 2s - loss: 0.0155 - mean_squared_error: 6.0792e-04 - val_loss: 0.0190 - val_mean_squared_error: 0.0022
#
# Epoch 00116: val_mean_squared_error did not improve from 0.00126
# Epoch 117/3000
#  - 2s - loss: 0.0154 - mean_squared_error: 6.9819e-04 - val_loss: 0.0194 - val_mean_squared_error: 0.0021
#
# Epoch 00117: val_mean_squared_error did not improve from 0.00126
# Epoch 118/3000
#  - 2s - loss: 0.0163 - mean_squared_error: 7.8555e-04 - val_loss: 0.0231 - val_mean_squared_error: 0.0031
#
# Epoch 00118: val_mean_squared_error did not improve from 0.00126
# Epoch 119/3000
#  - 2s - loss: 0.0155 - mean_squared_error: 5.9706e-04 - val_loss: 0.0192 - val_mean_squared_error: 0.0020
#
# Epoch 00119: val_mean_squared_error did not improve from 0.00126
# Epoch 120/3000
#  - 2s - loss: 0.0156 - mean_squared_error: 5.5044e-04 - val_loss: 0.0216 - val_mean_squared_error: 0.0025
#
# Epoch 00120: val_mean_squared_error did not improve from 0.00126
# Epoch 121/3000
#  - 2s - loss: 0.0141 - mean_squared_error: 4.9938e-04 - val_loss: 0.0260 - val_mean_squared_error: 0.0045
#
# Epoch 00121: val_mean_squared_error did not improve from 0.00126
# Epoch 122/3000
#  - 2s - loss: 0.0157 - mean_squared_error: 5.9730e-04 - val_loss: 0.0213 - val_mean_squared_error: 0.0023
#
# Epoch 00122: val_mean_squared_error did not improve from 0.00126
# Epoch 123/3000
#  - 2s - loss: 0.0169 - mean_squared_error: 9.1276e-04 - val_loss: 0.0245 - val_mean_squared_error: 0.0028
#
# Epoch 00123: val_mean_squared_error did not improve from 0.00126
# Epoch 124/3000
#  - 2s - loss: 0.0170 - mean_squared_error: 8.3296e-04 - val_loss: 0.0313 - val_mean_squared_error: 0.0061
#
# Epoch 00124: val_mean_squared_error did not improve from 0.00126
# Epoch 125/3000
#  - 2s - loss: 0.0164 - mean_squared_error: 9.7000e-04 - val_loss: 0.0358 - val_mean_squared_error: 0.0069
#
# Epoch 00125: val_mean_squared_error did not improve from 0.00126
# Epoch 126/3000
#  - 2s - loss: 0.0172 - mean_squared_error: 9.6007e-04 - val_loss: 0.0233 - val_mean_squared_error: 0.0027
#
# Epoch 00126: val_mean_squared_error did not improve from 0.00126
# Epoch 127/3000
#  - 2s - loss: 0.0222 - mean_squared_error: 0.0032 - val_loss: 0.0220 - val_mean_squared_error: 0.0029
#
# Epoch 00127: val_mean_squared_error did not improve from 0.00126
# Epoch 128/3000
#  - 2s - loss: 0.0192 - mean_squared_error: 0.0014 - val_loss: 0.0268 - val_mean_squared_error: 0.0027
#
# Epoch 00128: val_mean_squared_error did not improve from 0.00126
# Epoch 129/3000
#  - 2s - loss: 0.0173 - mean_squared_error: 8.8770e-04 - val_loss: 0.0214 - val_mean_squared_error: 0.0026
#
# Epoch 00129: val_mean_squared_error did not improve from 0.00126
# Epoch 130/3000
#  - 2s - loss: 0.0165 - mean_squared_error: 7.9962e-04 - val_loss: 0.0350 - val_mean_squared_error: 0.0053
#
# Epoch 00130: val_mean_squared_error did not improve from 0.00126
# Epoch 131/3000
#  - 2s - loss: 0.0167 - mean_squared_error: 6.9322e-04 - val_loss: 0.0529 - val_mean_squared_error: 0.0122
#
# Epoch 00131: val_mean_squared_error did not improve from 0.00126
# Epoch 132/3000
#  - 2s - loss: 0.0161 - mean_squared_error: 7.8494e-04 - val_loss: 0.0287 - val_mean_squared_error: 0.0039
#
# Epoch 00132: val_mean_squared_error did not improve from 0.00126
# Epoch 133/3000
#  - 2s - loss: 0.0184 - mean_squared_error: 0.0017 - val_loss: 0.0242 - val_mean_squared_error: 0.0037
#
# Epoch 00133: val_mean_squared_error did not improve from 0.00126
# Epoch 134/3000
#  - 2s - loss: 0.0165 - mean_squared_error: 7.7806e-04 - val_loss: 0.0256 - val_mean_squared_error: 0.0046
#
# Epoch 00134: val_mean_squared_error did not improve from 0.00126
# Epoch 135/3000
#  - 2s - loss: 0.0165 - mean_squared_error: 9.7982e-04 - val_loss: 0.0255 - val_mean_squared_error: 0.0033
#
# Epoch 00135: val_mean_squared_error did not improve from 0.00126
# Epoch 136/3000
#  - 2s - loss: 0.0163 - mean_squared_error: 8.5110e-04 - val_loss: 0.0227 - val_mean_squared_error: 0.0028
#
# Epoch 00136: val_mean_squared_error did not improve from 0.00126
# Epoch 137/3000
#  - 2s - loss: 0.0159 - mean_squared_error: 8.1179e-04 - val_loss: 0.0260 - val_mean_squared_error: 0.0030
#
# Epoch 00137: val_mean_squared_error did not improve from 0.00126
# Epoch 138/3000
#  - 2s - loss: 0.0167 - mean_squared_error: 0.0011 - val_loss: 0.0233 - val_mean_squared_error: 0.0033
#
# Epoch 00138: val_mean_squared_error did not improve from 0.00126
# Epoch 139/3000
#  - 2s - loss: 0.0154 - mean_squared_error: 7.0145e-04 - val_loss: 0.0272 - val_mean_squared_error: 0.0053
#
# Epoch 00139: val_mean_squared_error did not improve from 0.00126
# Epoch 140/3000
#  - 2s - loss: 0.0147 - mean_squared_error: 6.1018e-04 - val_loss: 0.0234 - val_mean_squared_error: 0.0038
#
# Epoch 00140: val_mean_squared_error did not improve from 0.00126
# Epoch 141/3000
#  - 2s - loss: 0.0149 - mean_squared_error: 5.7816e-04 - val_loss: 0.0204 - val_mean_squared_error: 0.0025
#
# Epoch 00141: val_mean_squared_error did not improve from 0.00126
# Epoch 142/3000
#  - 2s - loss: 0.0147 - mean_squared_error: 4.6591e-04 - val_loss: 0.0216 - val_mean_squared_error: 0.0025
#
# Epoch 00142: val_mean_squared_error did not improve from 0.00126
# Epoch 143/3000
#  - 2s - loss: 0.0155 - mean_squared_error: 7.0356e-04 - val_loss: 0.0177 - val_mean_squared_error: 0.0017
#
# Epoch 00143: val_mean_squared_error did not improve from 0.00126
# Epoch 144/3000
#  - 2s - loss: 0.0143 - mean_squared_error: 4.6416e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0023
#
# Epoch 00144: val_mean_squared_error did not improve from 0.00126
# Epoch 145/3000
#  - 2s - loss: 0.0141 - mean_squared_error: 5.2523e-04 - val_loss: 0.0191 - val_mean_squared_error: 0.0024
#
# Epoch 00145: val_mean_squared_error did not improve from 0.00126
# Epoch 146/3000
#  - 2s - loss: 0.0135 - mean_squared_error: 4.3287e-04 - val_loss: 0.0240 - val_mean_squared_error: 0.0039
#
# Epoch 00146: val_mean_squared_error did not improve from 0.00126
# Epoch 147/3000
#  - 2s - loss: 0.0144 - mean_squared_error: 4.1222e-04 - val_loss: 0.0227 - val_mean_squared_error: 0.0035
#
# Epoch 00147: val_mean_squared_error did not improve from 0.00126
# Epoch 148/3000
#  - 2s - loss: 0.0139 - mean_squared_error: 4.1298e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0023
#
# Epoch 00148: val_mean_squared_error did not improve from 0.00126
# Epoch 149/3000
#  - 2s - loss: 0.0140 - mean_squared_error: 4.2559e-04 - val_loss: 0.0216 - val_mean_squared_error: 0.0034
#
# Epoch 00149: val_mean_squared_error did not improve from 0.00126
# Epoch 150/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 3.7693e-04 - val_loss: 0.0254 - val_mean_squared_error: 0.0042
#
# Epoch 00150: val_mean_squared_error did not improve from 0.00126
# Epoch 151/3000
#  - 2s - loss: 0.0135 - mean_squared_error: 4.1318e-04 - val_loss: 0.0202 - val_mean_squared_error: 0.0027
#
# Epoch 00151: val_mean_squared_error did not improve from 0.00126
# Epoch 152/3000
#  - 2s - loss: 0.0139 - mean_squared_error: 3.9576e-04 - val_loss: 0.0175 - val_mean_squared_error: 0.0021
#
# Epoch 00152: val_mean_squared_error did not improve from 0.00126
# Epoch 153/3000
#  - 2s - loss: 0.0140 - mean_squared_error: 3.8968e-04 - val_loss: 0.0188 - val_mean_squared_error: 0.0024
#
# Epoch 00153: val_mean_squared_error did not improve from 0.00126
# Epoch 154/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 4.3548e-04 - val_loss: 0.0211 - val_mean_squared_error: 0.0037
#
# Epoch 00154: val_mean_squared_error did not improve from 0.00126
# Epoch 155/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 3.6313e-04 - val_loss: 0.0253 - val_mean_squared_error: 0.0050
#
# Epoch 00155: val_mean_squared_error did not improve from 0.00126
# Epoch 156/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 3.8211e-04 - val_loss: 0.0253 - val_mean_squared_error: 0.0046
#
# Epoch 00156: val_mean_squared_error did not improve from 0.00126
# Epoch 157/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 4.2222e-04 - val_loss: 0.0275 - val_mean_squared_error: 0.0050
#
# Epoch 00157: val_mean_squared_error did not improve from 0.00126
# Epoch 158/3000
#  - 2s - loss: 0.0148 - mean_squared_error: 5.0144e-04 - val_loss: 0.0260 - val_mean_squared_error: 0.0046
#
# Epoch 00158: val_mean_squared_error did not improve from 0.00126
# Epoch 159/3000
#  - 2s - loss: 0.0131 - mean_squared_error: 4.2835e-04 - val_loss: 0.0200 - val_mean_squared_error: 0.0023
#
# Epoch 00159: val_mean_squared_error did not improve from 0.00126
# Epoch 160/3000
#  - 2s - loss: 0.0136 - mean_squared_error: 4.2620e-04 - val_loss: 0.0189 - val_mean_squared_error: 0.0028
#
# Epoch 00160: val_mean_squared_error did not improve from 0.00126
# Epoch 161/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 4.2041e-04 - val_loss: 0.0237 - val_mean_squared_error: 0.0033
#
# Epoch 00161: val_mean_squared_error did not improve from 0.00126
# Epoch 162/3000
#  - 2s - loss: 0.0138 - mean_squared_error: 4.7701e-04 - val_loss: 0.0253 - val_mean_squared_error: 0.0046
#
# Epoch 00162: val_mean_squared_error did not improve from 0.00126
# Epoch 163/3000
#  - 2s - loss: 0.0155 - mean_squared_error: 0.0011 - val_loss: 0.0287 - val_mean_squared_error: 0.0056
#
# Epoch 00163: val_mean_squared_error did not improve from 0.00126
# Epoch 164/3000
#  - 2s - loss: 0.0145 - mean_squared_error: 4.8776e-04 - val_loss: 0.0317 - val_mean_squared_error: 0.0061
#
# Epoch 00164: val_mean_squared_error did not improve from 0.00126
# Epoch 165/3000
#  - 2s - loss: 0.0136 - mean_squared_error: 4.4257e-04 - val_loss: 0.0209 - val_mean_squared_error: 0.0024
#
# Epoch 00165: val_mean_squared_error did not improve from 0.00126
# Epoch 166/3000
#  - 2s - loss: 0.0141 - mean_squared_error: 4.2757e-04 - val_loss: 0.0177 - val_mean_squared_error: 0.0020
#
# Epoch 00166: val_mean_squared_error did not improve from 0.00126
# Epoch 167/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.5323e-04 - val_loss: 0.0162 - val_mean_squared_error: 0.0014
#
# Epoch 00167: val_mean_squared_error did not improve from 0.00126
# Epoch 168/3000
#  - 2s - loss: 0.0130 - mean_squared_error: 3.5743e-04 - val_loss: 0.0196 - val_mean_squared_error: 0.0022
#
# Epoch 00168: val_mean_squared_error did not improve from 0.00126
# Epoch 169/3000
#  - 2s - loss: 0.0135 - mean_squared_error: 3.9020e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0017
#
# Epoch 00169: val_mean_squared_error did not improve from 0.00126
# Epoch 170/3000
#  - 2s - loss: 0.0133 - mean_squared_error: 3.8598e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0020
#
# Epoch 00170: val_mean_squared_error did not improve from 0.00126
# Epoch 171/3000
#  - 2s - loss: 0.0129 - mean_squared_error: 3.6911e-04 - val_loss: 0.0203 - val_mean_squared_error: 0.0029
#
# Epoch 00171: val_mean_squared_error did not improve from 0.00126
# Epoch 172/3000
#  - 2s - loss: 0.0131 - mean_squared_error: 3.9179e-04 - val_loss: 0.0221 - val_mean_squared_error: 0.0029
#
# Epoch 00172: val_mean_squared_error did not improve from 0.00126
# Epoch 173/3000
#  - 2s - loss: 0.0131 - mean_squared_error: 5.1830e-04 - val_loss: 0.0249 - val_mean_squared_error: 0.0037
#
# Epoch 00173: val_mean_squared_error did not improve from 0.00126
# Epoch 174/3000
#  - 2s - loss: 0.0128 - mean_squared_error: 3.4514e-04 - val_loss: 0.0237 - val_mean_squared_error: 0.0035
#
# Epoch 00174: val_mean_squared_error did not improve from 0.00126
# Epoch 175/3000
#  - 2s - loss: 0.0126 - mean_squared_error: 4.8090e-04 - val_loss: 0.0200 - val_mean_squared_error: 0.0027
#
# Epoch 00175: val_mean_squared_error did not improve from 0.00126
# Epoch 176/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 3.5211e-04 - val_loss: 0.0219 - val_mean_squared_error: 0.0033
#
# Epoch 00176: val_mean_squared_error did not improve from 0.00126
# Epoch 177/3000
#  - 2s - loss: 0.0122 - mean_squared_error: 3.6822e-04 - val_loss: 0.0192 - val_mean_squared_error: 0.0027
#
# Epoch 00177: val_mean_squared_error did not improve from 0.00126
# Epoch 178/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.2134e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0018
#
# Epoch 00178: val_mean_squared_error did not improve from 0.00126
# Epoch 179/3000
#  - 2s - loss: 0.0125 - mean_squared_error: 3.5830e-04 - val_loss: 0.0175 - val_mean_squared_error: 0.0021
#
# Epoch 00179: val_mean_squared_error did not improve from 0.00126
# Epoch 180/3000
#  - 2s - loss: 0.0121 - mean_squared_error: 2.8662e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0024
#
# Epoch 00180: val_mean_squared_error did not improve from 0.00126
# Epoch 181/3000
#  - 2s - loss: 0.0133 - mean_squared_error: 3.7970e-04 - val_loss: 0.0177 - val_mean_squared_error: 0.0020
#
# Epoch 00181: val_mean_squared_error did not improve from 0.00126
# Epoch 182/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.4779e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0021
#
# Epoch 00182: val_mean_squared_error did not improve from 0.00126
# Epoch 183/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 4.8365e-04 - val_loss: 0.0216 - val_mean_squared_error: 0.0029
#
# Epoch 00183: val_mean_squared_error did not improve from 0.00126
# Epoch 184/3000
#  - 2s - loss: 0.0130 - mean_squared_error: 4.1869e-04 - val_loss: 0.0211 - val_mean_squared_error: 0.0028
#
# Epoch 00184: val_mean_squared_error did not improve from 0.00126
# Epoch 185/3000
#  - 2s - loss: 0.0120 - mean_squared_error: 3.1267e-04 - val_loss: 0.0182 - val_mean_squared_error: 0.0019
#
# Epoch 00185: val_mean_squared_error did not improve from 0.00126
# Epoch 186/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.4178e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0015
#
# Epoch 00186: val_mean_squared_error did not improve from 0.00126
# Epoch 187/3000
#  - 2s - loss: 0.0126 - mean_squared_error: 4.4816e-04 - val_loss: 0.0143 - val_mean_squared_error: 7.3625e-04
#
# Epoch 00187: val_mean_squared_error improved from 0.00126 to 0.00074, saving model to weights.best1.hdf5
# Epoch 188/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 5.1778e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0017
#
# Epoch 00188: val_mean_squared_error did not improve from 0.00074
# Epoch 189/3000
#  - 2s - loss: 0.0143 - mean_squared_error: 7.0481e-04 - val_loss: 0.0360 - val_mean_squared_error: 0.0081
#
# Epoch 00189: val_mean_squared_error did not improve from 0.00074
# Epoch 190/3000
#  - 2s - loss: 0.0136 - mean_squared_error: 5.3286e-04 - val_loss: 0.0342 - val_mean_squared_error: 0.0108
#
# Epoch 00190: val_mean_squared_error did not improve from 0.00074
# Epoch 191/3000
#  - 2s - loss: 0.0141 - mean_squared_error: 7.7688e-04 - val_loss: 0.0242 - val_mean_squared_error: 0.0037
#
# Epoch 00191: val_mean_squared_error did not improve from 0.00074
# Epoch 192/3000
#  - 2s - loss: 0.0129 - mean_squared_error: 4.5292e-04 - val_loss: 0.0212 - val_mean_squared_error: 0.0032
#
# Epoch 00192: val_mean_squared_error did not improve from 0.00074
# Epoch 193/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 4.6196e-04 - val_loss: 0.0214 - val_mean_squared_error: 0.0040
#
# Epoch 00193: val_mean_squared_error did not improve from 0.00074
# Epoch 194/3000
#  - 2s - loss: 0.0126 - mean_squared_error: 4.3855e-04 - val_loss: 0.0270 - val_mean_squared_error: 0.0056
#
# Epoch 00194: val_mean_squared_error did not improve from 0.00074
# Epoch 195/3000
#  - 2s - loss: 0.0142 - mean_squared_error: 8.2655e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0015
#
# Epoch 00195: val_mean_squared_error did not improve from 0.00074
# Epoch 196/3000
#  - 2s - loss: 0.0143 - mean_squared_error: 7.0316e-04 - val_loss: 0.0162 - val_mean_squared_error: 0.0016
#
# Epoch 00196: val_mean_squared_error did not improve from 0.00074
# Epoch 197/3000
#  - 2s - loss: 0.0136 - mean_squared_error: 6.4723e-04 - val_loss: 0.0185 - val_mean_squared_error: 0.0023
#
# Epoch 00197: val_mean_squared_error did not improve from 0.00074
# Epoch 198/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 4.4089e-04 - val_loss: 0.0185 - val_mean_squared_error: 0.0023
#
# Epoch 00198: val_mean_squared_error did not improve from 0.00074
# Epoch 199/3000
#  - 2s - loss: 0.0137 - mean_squared_error: 5.3108e-04 - val_loss: 0.0226 - val_mean_squared_error: 0.0039
#
# Epoch 00199: val_mean_squared_error did not improve from 0.00074
# Epoch 200/3000
#  - 2s - loss: 0.0129 - mean_squared_error: 4.3442e-04 - val_loss: 0.0243 - val_mean_squared_error: 0.0039
#
# Epoch 00200: val_mean_squared_error did not improve from 0.00074
# Epoch 201/3000
#  - 2s - loss: 0.0124 - mean_squared_error: 3.8045e-04 - val_loss: 0.0170 - val_mean_squared_error: 0.0020
#
# Epoch 00201: val_mean_squared_error did not improve from 0.00074
# Epoch 202/3000
#  - 2s - loss: 0.0119 - mean_squared_error: 2.8778e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0017
#
# Epoch 00202: val_mean_squared_error did not improve from 0.00074
# Epoch 203/3000
#  - 2s - loss: 0.0119 - mean_squared_error: 2.9260e-04 - val_loss: 0.0177 - val_mean_squared_error: 0.0023
#
# Epoch 00203: val_mean_squared_error did not improve from 0.00074
# Epoch 204/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 4.7427e-04 - val_loss: 0.0176 - val_mean_squared_error: 0.0017
#
# Epoch 00204: val_mean_squared_error did not improve from 0.00074
# Epoch 205/3000
#  - 2s - loss: 0.0128 - mean_squared_error: 3.6321e-04 - val_loss: 0.0231 - val_mean_squared_error: 0.0037
#
# Epoch 00205: val_mean_squared_error did not improve from 0.00074
# Epoch 206/3000
#  - 2s - loss: 0.0133 - mean_squared_error: 4.8550e-04 - val_loss: 0.0221 - val_mean_squared_error: 0.0035
#
# Epoch 00206: val_mean_squared_error did not improve from 0.00074
# Epoch 207/3000
#  - 2s - loss: 0.0124 - mean_squared_error: 3.4218e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0023
#
# Epoch 00207: val_mean_squared_error did not improve from 0.00074
# Epoch 208/3000
#  - 2s - loss: 0.0126 - mean_squared_error: 5.4180e-04 - val_loss: 0.0170 - val_mean_squared_error: 0.0022
#
# Epoch 00208: val_mean_squared_error did not improve from 0.00074
# Epoch 209/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 5.3471e-04 - val_loss: 0.0159 - val_mean_squared_error: 0.0015
#
# Epoch 00209: val_mean_squared_error did not improve from 0.00074
# Epoch 210/3000
#  - 2s - loss: 0.0122 - mean_squared_error: 4.5452e-04 - val_loss: 0.0313 - val_mean_squared_error: 0.0067
#
# Epoch 00210: val_mean_squared_error did not improve from 0.00074
# Epoch 211/3000
#  - 2s - loss: 0.0124 - mean_squared_error: 3.4015e-04 - val_loss: 0.0270 - val_mean_squared_error: 0.0050
#
# Epoch 00211: val_mean_squared_error did not improve from 0.00074
# Epoch 212/3000
#  - 2s - loss: 0.0124 - mean_squared_error: 3.0952e-04 - val_loss: 0.0200 - val_mean_squared_error: 0.0032
#
# Epoch 00212: val_mean_squared_error did not improve from 0.00074
# Epoch 213/3000
#  - 2s - loss: 0.0115 - mean_squared_error: 3.0580e-04 - val_loss: 0.0194 - val_mean_squared_error: 0.0025
#
# Epoch 00213: val_mean_squared_error did not improve from 0.00074
# Epoch 214/3000
#  - 2s - loss: 0.0125 - mean_squared_error: 3.8546e-04 - val_loss: 0.0173 - val_mean_squared_error: 0.0023
#
# Epoch 00214: val_mean_squared_error did not improve from 0.00074
# Epoch 215/3000
#  - 2s - loss: 0.0124 - mean_squared_error: 4.8129e-04 - val_loss: 0.0176 - val_mean_squared_error: 0.0021
#
# Epoch 00215: val_mean_squared_error did not improve from 0.00074
# Epoch 216/3000
#  - 2s - loss: 0.0130 - mean_squared_error: 4.1374e-04 - val_loss: 0.0149 - val_mean_squared_error: 0.0019
#
# Epoch 00216: val_mean_squared_error did not improve from 0.00074
# Epoch 217/3000
#  - 2s - loss: 0.0123 - mean_squared_error: 3.7056e-04 - val_loss: 0.0238 - val_mean_squared_error: 0.0040
#
# Epoch 00217: val_mean_squared_error did not improve from 0.00074
# Epoch 218/3000
#  - 2s - loss: 0.0126 - mean_squared_error: 4.1873e-04 - val_loss: 0.0208 - val_mean_squared_error: 0.0029
#
# Epoch 00218: val_mean_squared_error did not improve from 0.00074
# Epoch 219/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 6.0254e-04 - val_loss: 0.0237 - val_mean_squared_error: 0.0045
#
# Epoch 00219: val_mean_squared_error did not improve from 0.00074
# Epoch 220/3000
#  - 2s - loss: 0.0121 - mean_squared_error: 3.5044e-04 - val_loss: 0.0289 - val_mean_squared_error: 0.0061
#
# Epoch 00220: val_mean_squared_error did not improve from 0.00074
# Epoch 221/3000
#  - 2s - loss: 0.0128 - mean_squared_error: 3.4453e-04 - val_loss: 0.0391 - val_mean_squared_error: 0.0104
#
# Epoch 00221: val_mean_squared_error did not improve from 0.00074
# Epoch 222/3000
#  - 2s - loss: 0.0118 - mean_squared_error: 3.1179e-04 - val_loss: 0.0273 - val_mean_squared_error: 0.0053
#
# Epoch 00222: val_mean_squared_error did not improve from 0.00074
# Epoch 223/3000
#  - 2s - loss: 0.0122 - mean_squared_error: 3.4884e-04 - val_loss: 0.0176 - val_mean_squared_error: 0.0023
#
# Epoch 00223: val_mean_squared_error did not improve from 0.00074
# Epoch 224/3000
#  - 2s - loss: 0.0114 - mean_squared_error: 2.8286e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0022
#
# Epoch 00224: val_mean_squared_error did not improve from 0.00074
# Epoch 225/3000
#  - 2s - loss: 0.0114 - mean_squared_error: 3.1406e-04 - val_loss: 0.0171 - val_mean_squared_error: 0.0021
#
# Epoch 00225: val_mean_squared_error did not improve from 0.00074
# Epoch 226/3000
#  - 2s - loss: 0.0117 - mean_squared_error: 3.2054e-04 - val_loss: 0.0193 - val_mean_squared_error: 0.0032
#
# Epoch 00226: val_mean_squared_error did not improve from 0.00074
# Epoch 227/3000
#  - 2s - loss: 0.0114 - mean_squared_error: 2.8937e-04 - val_loss: 0.0150 - val_mean_squared_error: 0.0015
#
# Epoch 00227: val_mean_squared_error did not improve from 0.00074
# Epoch 228/3000
#  - 2s - loss: 0.0122 - mean_squared_error: 4.3543e-04 - val_loss: 0.0136 - val_mean_squared_error: 0.0014
#
# Epoch 00228: val_mean_squared_error did not improve from 0.00074
# Epoch 229/3000
#  - 2s - loss: 0.0119 - mean_squared_error: 3.6606e-04 - val_loss: 0.0152 - val_mean_squared_error: 0.0017
#
# Epoch 00229: val_mean_squared_error did not improve from 0.00074
# Epoch 230/3000
#  - 2s - loss: 0.0116 - mean_squared_error: 3.1118e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0019
#
# Epoch 00230: val_mean_squared_error did not improve from 0.00074
# Epoch 231/3000
#  - 2s - loss: 0.0117 - mean_squared_error: 2.8792e-04 - val_loss: 0.0188 - val_mean_squared_error: 0.0022
#
# Epoch 00231: val_mean_squared_error did not improve from 0.00074
# Epoch 232/3000
#  - 2s - loss: 0.0120 - mean_squared_error: 3.3616e-04 - val_loss: 0.0163 - val_mean_squared_error: 0.0019
#
# Epoch 00232: val_mean_squared_error did not improve from 0.00074
# Epoch 233/3000
#  - 2s - loss: 0.0112 - mean_squared_error: 3.4226e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0018
#
# Epoch 00233: val_mean_squared_error did not improve from 0.00074
# Epoch 234/3000
#  - 2s - loss: 0.0114 - mean_squared_error: 2.9863e-04 - val_loss: 0.0161 - val_mean_squared_error: 0.0018
#
# Epoch 00234: val_mean_squared_error did not improve from 0.00074
# Epoch 235/3000
#  - 2s - loss: 0.0114 - mean_squared_error: 3.4593e-04 - val_loss: 0.0177 - val_mean_squared_error: 0.0023
#
# Epoch 00235: val_mean_squared_error did not improve from 0.00074
# Epoch 236/3000
#  - 2s - loss: 0.0115 - mean_squared_error: 2.7177e-04 - val_loss: 0.0141 - val_mean_squared_error: 0.0014
#
# Epoch 00236: val_mean_squared_error did not improve from 0.00074
# Epoch 237/3000
#  - 2s - loss: 0.0111 - mean_squared_error: 2.5995e-04 - val_loss: 0.0151 - val_mean_squared_error: 0.0017
#
# Epoch 00237: val_mean_squared_error did not improve from 0.00074
# Epoch 238/3000
#  - 2s - loss: 0.0111 - mean_squared_error: 2.5808e-04 - val_loss: 0.0151 - val_mean_squared_error: 0.0015
#
# Epoch 00238: val_mean_squared_error did not improve from 0.00074
# Epoch 239/3000
#  - 2s - loss: 0.0116 - mean_squared_error: 3.5440e-04 - val_loss: 0.0149 - val_mean_squared_error: 0.0017
#
# Epoch 00239: val_mean_squared_error did not improve from 0.00074
# Epoch 240/3000
#  - 2s - loss: 0.0115 - mean_squared_error: 3.9974e-04 - val_loss: 0.0144 - val_mean_squared_error: 0.0014
#
# Epoch 00240: val_mean_squared_error did not improve from 0.00074
# Epoch 241/3000
#  - 2s - loss: 0.0116 - mean_squared_error: 4.4448e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0015
#
# Epoch 00241: val_mean_squared_error did not improve from 0.00074
# Epoch 242/3000
#  - 2s - loss: 0.0114 - mean_squared_error: 2.7146e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0029
#
# Epoch 00242: val_mean_squared_error did not improve from 0.00074
# Epoch 243/3000
#  - 2s - loss: 0.0112 - mean_squared_error: 2.5106e-04 - val_loss: 0.0193 - val_mean_squared_error: 0.0037
#
# Epoch 00243: val_mean_squared_error did not improve from 0.00074
# Epoch 244/3000
#  - 2s - loss: 0.0109 - mean_squared_error: 2.6012e-04 - val_loss: 0.0205 - val_mean_squared_error: 0.0041
#
# Epoch 00244: val_mean_squared_error did not improve from 0.00074
# Epoch 245/3000
#  - 2s - loss: 0.0112 - mean_squared_error: 2.9201e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0028
#
# Epoch 00245: val_mean_squared_error did not improve from 0.00074
# Epoch 246/3000
#  - 2s - loss: 0.0109 - mean_squared_error: 2.5598e-04 - val_loss: 0.0153 - val_mean_squared_error: 0.0017
#
# Epoch 00246: val_mean_squared_error did not improve from 0.00074
# Epoch 247/3000
#  - 2s - loss: 0.0112 - mean_squared_error: 2.9328e-04 - val_loss: 0.0136 - val_mean_squared_error: 0.0014
#
# Epoch 00247: val_mean_squared_error did not improve from 0.00074
# Epoch 248/3000
#  - 2s - loss: 0.0104 - mean_squared_error: 2.1978e-04 - val_loss: 0.0143 - val_mean_squared_error: 0.0016
#
# Epoch 00248: val_mean_squared_error did not improve from 0.00074
# Epoch 249/3000
#  - 2s - loss: 0.0105 - mean_squared_error: 2.3826e-04 - val_loss: 0.0163 - val_mean_squared_error: 0.0018
#
# Epoch 00249: val_mean_squared_error did not improve from 0.00074
# Epoch 250/3000
#  - 2s - loss: 0.0118 - mean_squared_error: 4.1132e-04 - val_loss: 0.0182 - val_mean_squared_error: 0.0034
#
# Epoch 00250: val_mean_squared_error did not improve from 0.00074
# Epoch 251/3000
#  - 2s - loss: 0.0125 - mean_squared_error: 7.4960e-04 - val_loss: 0.0212 - val_mean_squared_error: 0.0038
#
# Epoch 00251: val_mean_squared_error did not improve from 0.00074
# Epoch 252/3000
#  - 2s - loss: 0.0119 - mean_squared_error: 4.6879e-04 - val_loss: 0.0241 - val_mean_squared_error: 0.0050
#
# Epoch 00252: val_mean_squared_error did not improve from 0.00074
# Epoch 253/3000
#  - 2s - loss: 0.0126 - mean_squared_error: 4.7225e-04 - val_loss: 0.0170 - val_mean_squared_error: 0.0025
#
# Epoch 00253: val_mean_squared_error did not improve from 0.00074
# Epoch 254/3000
#  - 2s - loss: 0.0117 - mean_squared_error: 3.6964e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0022
#
# ...
# Epoch 2916/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.7222e-04 - val_loss: 0.0143 - val_mean_squared_error: 0.0019
#
# Epoch 02916: val_mean_squared_error did not improve from 0.00042
# Epoch 2917/3000
#  - 2s - loss: 0.0094 - mean_squared_error: 1.9860e-04 - val_loss: 0.0140 - val_mean_squared_error: 0.0019
#
# Epoch 02917: val_mean_squared_error did not improve from 0.00042
# Epoch 2918/3000
#  - 2s - loss: 0.0093 - mean_squared_error: 2.1931e-04 - val_loss: 0.0138 - val_mean_squared_error: 0.0019
#
# Epoch 02918: val_mean_squared_error did not improve from 0.00042
# Epoch 2919/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 2.2565e-04 - val_loss: 0.0138 - val_mean_squared_error: 0.0019
#
# Epoch 02919: val_mean_squared_error did not improve from 0.00042
# Epoch 2920/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.5329e-04 - val_loss: 0.0135 - val_mean_squared_error: 0.0018
#
# Epoch 02920: val_mean_squared_error did not improve from 0.00042
# Epoch 2921/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 1.7681e-04 - val_loss: 0.0133 - val_mean_squared_error: 0.0018
#
# Epoch 02921: val_mean_squared_error did not improve from 0.00042
# Epoch 2922/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 2.9103e-04 - val_loss: 0.0124 - val_mean_squared_error: 0.0017
#
# Epoch 02922: val_mean_squared_error did not improve from 0.00042
# Epoch 2923/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4382e-04 - val_loss: 0.0128 - val_mean_squared_error: 0.0018
#
# Epoch 02923: val_mean_squared_error did not improve from 0.00042
# Epoch 2924/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.8361e-04 - val_loss: 0.0129 - val_mean_squared_error: 0.0018
#
# Epoch 02924: val_mean_squared_error did not improve from 0.00042
# Epoch 2925/3000
#  - 2s - loss: 0.0084 - mean_squared_error: 1.6178e-04 - val_loss: 0.0127 - val_mean_squared_error: 0.0017
#
# Epoch 02925: val_mean_squared_error did not improve from 0.00042
# Epoch 2926/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 2.1164e-04 - val_loss: 0.0131 - val_mean_squared_error: 0.0017
#
# Epoch 02926: val_mean_squared_error did not improve from 0.00042
# Epoch 2927/3000
#  - 2s - loss: 0.0097 - mean_squared_error: 3.7973e-04 - val_loss: 0.0163 - val_mean_squared_error: 0.0021
#
# Epoch 02927: val_mean_squared_error did not improve from 0.00042
# Epoch 2928/3000
#  - 2s - loss: 0.0097 - mean_squared_error: 3.2983e-04 - val_loss: 0.0160 - val_mean_squared_error: 0.0023
#
# Epoch 02928: val_mean_squared_error did not improve from 0.00042
# Epoch 2929/3000
#  - 2s - loss: 0.0096 - mean_squared_error: 2.5986e-04 - val_loss: 0.0195 - val_mean_squared_error: 0.0040
#
# Epoch 02929: val_mean_squared_error did not improve from 0.00042
# Epoch 2930/3000
#  - 2s - loss: 0.0098 - mean_squared_error: 2.8778e-04 - val_loss: 0.0192 - val_mean_squared_error: 0.0041
#
# Epoch 02930: val_mean_squared_error did not improve from 0.00042
# Epoch 2931/3000
#  - 2s - loss: 0.0094 - mean_squared_error: 2.2256e-04 - val_loss: 0.0181 - val_mean_squared_error: 0.0037
#
# Epoch 02931: val_mean_squared_error did not improve from 0.00042
# Epoch 2932/3000
#  - 2s - loss: 0.0097 - mean_squared_error: 3.0219e-04 - val_loss: 0.0187 - val_mean_squared_error: 0.0040
#
# Epoch 02932: val_mean_squared_error did not improve from 0.00042
# Epoch 2933/3000
#  - 2s - loss: 0.0093 - mean_squared_error: 2.4013e-04 - val_loss: 0.0177 - val_mean_squared_error: 0.0036
#
# Epoch 02933: val_mean_squared_error did not improve from 0.00042
# Epoch 2934/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 2.1465e-04 - val_loss: 0.0176 - val_mean_squared_error: 0.0035
#
# Epoch 02934: val_mean_squared_error did not improve from 0.00042
# Epoch 2935/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 2.1344e-04 - val_loss: 0.0152 - val_mean_squared_error: 0.0023
#
# Epoch 02935: val_mean_squared_error did not improve from 0.00042
# Epoch 2936/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.8069e-04 - val_loss: 0.0145 - val_mean_squared_error: 0.0021
#
# Epoch 02936: val_mean_squared_error did not improve from 0.00042
# Epoch 2937/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 1.8036e-04 - val_loss: 0.0144 - val_mean_squared_error: 0.0020
#
# Epoch 02937: val_mean_squared_error did not improve from 0.00042
# Epoch 2938/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.4231e-04 - val_loss: 0.0144 - val_mean_squared_error: 0.0020
#
# Epoch 02938: val_mean_squared_error did not improve from 0.00042
# Epoch 2939/3000
#  - 2s - loss: 0.0092 - mean_squared_error: 2.2770e-04 - val_loss: 0.0179 - val_mean_squared_error: 0.0024
#
# Epoch 02939: val_mean_squared_error did not improve from 0.00042
# Epoch 2940/3000
#  - 2s - loss: 0.0103 - mean_squared_error: 3.7506e-04 - val_loss: 0.0152 - val_mean_squared_error: 0.0019
#
# Epoch 02940: val_mean_squared_error did not improve from 0.00042
# Epoch 2941/3000
#  - 2s - loss: 0.0095 - mean_squared_error: 2.7461e-04 - val_loss: 0.0140 - val_mean_squared_error: 0.0018
#
# Epoch 02941: val_mean_squared_error did not improve from 0.00042
# Epoch 2942/3000
#  - 2s - loss: 0.0092 - mean_squared_error: 1.7448e-04 - val_loss: 0.0139 - val_mean_squared_error: 0.0017
#
# Epoch 02942: val_mean_squared_error did not improve from 0.00042
# Epoch 2943/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.7276e-04 - val_loss: 0.0128 - val_mean_squared_error: 0.0015
#
# Epoch 02943: val_mean_squared_error did not improve from 0.00042
# Epoch 2944/3000
#  - 2s - loss: 0.0092 - mean_squared_error: 1.7384e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0014
#
# Epoch 02944: val_mean_squared_error did not improve from 0.00042
# Epoch 2945/3000
#  - 2s - loss: 0.0092 - mean_squared_error: 2.5190e-04 - val_loss: 0.0129 - val_mean_squared_error: 0.0014
#
# Epoch 02945: val_mean_squared_error did not improve from 0.00042
# Epoch 2946/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.5246e-04 - val_loss: 0.0125 - val_mean_squared_error: 0.0014
#
# Epoch 02946: val_mean_squared_error did not improve from 0.00042
# Epoch 2947/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.8384e-04 - val_loss: 0.0128 - val_mean_squared_error: 0.0014
#
# Epoch 02947: val_mean_squared_error did not improve from 0.00042
# Epoch 2948/3000
#  - 2s - loss: 0.0092 - mean_squared_error: 2.0909e-04 - val_loss: 0.0139 - val_mean_squared_error: 0.0014
#
# Epoch 02948: val_mean_squared_error did not improve from 0.00042
# Epoch 2949/3000
#  - 2s - loss: 0.0093 - mean_squared_error: 2.2184e-04 - val_loss: 0.0124 - val_mean_squared_error: 0.0013
#
# Epoch 02949: val_mean_squared_error did not improve from 0.00042
# Epoch 2950/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 1.7828e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0013
#
# Epoch 02950: val_mean_squared_error did not improve from 0.00042
# Epoch 2951/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4257e-04 - val_loss: 0.0122 - val_mean_squared_error: 0.0013
#
# Epoch 02951: val_mean_squared_error did not improve from 0.00042
# Epoch 2952/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.6732e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0013
#
# Epoch 02952: val_mean_squared_error did not improve from 0.00042
# Epoch 2953/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4140e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0014
#
# Epoch 02953: val_mean_squared_error did not improve from 0.00042
# Epoch 2954/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 2.1396e-04 - val_loss: 0.0127 - val_mean_squared_error: 0.0013
#
# Epoch 02954: val_mean_squared_error did not improve from 0.00042
# Epoch 2955/3000
#  - 2s - loss: 0.0095 - mean_squared_error: 2.5800e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0013
#
# Epoch 02955: val_mean_squared_error did not improve from 0.00042
# Epoch 2956/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.7719e-04 - val_loss: 0.0122 - val_mean_squared_error: 0.0013
#
# Epoch 02956: val_mean_squared_error did not improve from 0.00042
# Epoch 2957/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.5308e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0013
#
# Epoch 02957: val_mean_squared_error did not improve from 0.00042
# Epoch 2958/3000
#  - 2s - loss: 0.0094 - mean_squared_error: 2.8057e-04 - val_loss: 0.0122 - val_mean_squared_error: 0.0013
#
# Epoch 02958: val_mean_squared_error did not improve from 0.00042
# Epoch 2959/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.4957e-04 - val_loss: 0.0123 - val_mean_squared_error: 0.0014
#
# Epoch 02959: val_mean_squared_error did not improve from 0.00042
# Epoch 2960/3000
#  - 2s - loss: 0.0093 - mean_squared_error: 2.1872e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0014
#
# Epoch 02960: val_mean_squared_error did not improve from 0.00042
# Epoch 2961/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.4155e-04 - val_loss: 0.0128 - val_mean_squared_error: 0.0014
#
# Epoch 02961: val_mean_squared_error did not improve from 0.00042
# Epoch 2962/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.7137e-04 - val_loss: 0.0134 - val_mean_squared_error: 0.0017
#
# Epoch 02962: val_mean_squared_error did not improve from 0.00042
# Epoch 2963/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.6433e-04 - val_loss: 0.0131 - val_mean_squared_error: 0.0015
#
# Epoch 02963: val_mean_squared_error did not improve from 0.00042
# Epoch 2964/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 2.0173e-04 - val_loss: 0.0125 - val_mean_squared_error: 0.0015
#
# Epoch 02964: val_mean_squared_error did not improve from 0.00042
# Epoch 2965/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.7023e-04 - val_loss: 0.0124 - val_mean_squared_error: 0.0015
#
# Epoch 02965: val_mean_squared_error did not improve from 0.00042
# Epoch 2966/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 2.2123e-04 - val_loss: 0.0123 - val_mean_squared_error: 0.0015
#
# Epoch 02966: val_mean_squared_error did not improve from 0.00042
# Epoch 2967/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 2.4238e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0014
#
# Epoch 02967: val_mean_squared_error did not improve from 0.00042
# Epoch 2968/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4095e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0015
#
# Epoch 02968: val_mean_squared_error did not improve from 0.00042
# Epoch 2969/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4791e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0014
#
# Epoch 02969: val_mean_squared_error did not improve from 0.00042
# Epoch 2970/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 1.5659e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0015
#
# Epoch 02970: val_mean_squared_error did not improve from 0.00042
# Epoch 2971/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 1.6282e-04 - val_loss: 0.0125 - val_mean_squared_error: 0.0015
#
# Epoch 02971: val_mean_squared_error did not improve from 0.00042
# Epoch 2972/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4598e-04 - val_loss: 0.0123 - val_mean_squared_error: 0.0014
#
# Epoch 02972: val_mean_squared_error did not improve from 0.00042
# Epoch 2973/3000
#  - 2s - loss: 0.0085 - mean_squared_error: 1.3249e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0014
#
# Epoch 02973: val_mean_squared_error did not improve from 0.00042
# Epoch 2974/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 2.0316e-04 - val_loss: 0.0119 - val_mean_squared_error: 0.0014
#
# Epoch 02974: val_mean_squared_error did not improve from 0.00042
# Epoch 2975/3000
#  - 2s - loss: 0.0085 - mean_squared_error: 1.3419e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0015
#
# Epoch 02975: val_mean_squared_error did not improve from 0.00042
# Epoch 2976/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.7733e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0014
#
# Epoch 02976: val_mean_squared_error did not improve from 0.00042
# Epoch 2977/3000
#  - 2s - loss: 0.0085 - mean_squared_error: 1.4176e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0015
#
# Epoch 02977: val_mean_squared_error did not improve from 0.00042
# Epoch 2978/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 3.0057e-04 - val_loss: 0.0129 - val_mean_squared_error: 0.0017
#
# Epoch 02978: val_mean_squared_error did not improve from 0.00042
# Epoch 2979/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.3837e-04 - val_loss: 0.0128 - val_mean_squared_error: 0.0017
#
# Epoch 02979: val_mean_squared_error did not improve from 0.00042
# Epoch 2980/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.6172e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0016
#
# Epoch 02980: val_mean_squared_error did not improve from 0.00042
# Epoch 2981/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.8141e-04 - val_loss: 0.0123 - val_mean_squared_error: 0.0016
#
# Epoch 02981: val_mean_squared_error did not improve from 0.00042
# Epoch 2982/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.3646e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0015
#
# Epoch 02982: val_mean_squared_error did not improve from 0.00042
# Epoch 2983/3000
#  - 2s - loss: 0.0085 - mean_squared_error: 1.5624e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0015
#
# Epoch 02983: val_mean_squared_error did not improve from 0.00042
# Epoch 2984/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.3540e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0015
#
# Epoch 02984: val_mean_squared_error did not improve from 0.00042
# Epoch 2985/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.5268e-04 - val_loss: 0.0128 - val_mean_squared_error: 0.0015
#
# Epoch 02985: val_mean_squared_error did not improve from 0.00042
# Epoch 2986/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.8642e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0015
#
# Epoch 02986: val_mean_squared_error did not improve from 0.00042
# Epoch 2987/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.5739e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0015
#
# Epoch 02987: val_mean_squared_error did not improve from 0.00042
# Epoch 2988/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.5278e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0014
#
# Epoch 02988: val_mean_squared_error did not improve from 0.00042
# Epoch 2989/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.3970e-04 - val_loss: 0.0123 - val_mean_squared_error: 0.0015
#
# Epoch 02989: val_mean_squared_error did not improve from 0.00042
# Epoch 2990/3000
#  - 2s - loss: 0.0084 - mean_squared_error: 1.4978e-04 - val_loss: 0.0137 - val_mean_squared_error: 0.0018
#
# Epoch 02990: val_mean_squared_error did not improve from 0.00042
# Epoch 2991/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.7682e-04 - val_loss: 0.0133 - val_mean_squared_error: 0.0019
#
# Epoch 02991: val_mean_squared_error did not improve from 0.00042
# Epoch 2992/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.5002e-04 - val_loss: 0.0132 - val_mean_squared_error: 0.0019
#
# Epoch 02992: val_mean_squared_error did not improve from 0.00042
# Epoch 2993/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.3892e-04 - val_loss: 0.0135 - val_mean_squared_error: 0.0021
#
# Epoch 02993: val_mean_squared_error did not improve from 0.00042
# Epoch 2994/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.4503e-04 - val_loss: 0.0137 - val_mean_squared_error: 0.0023
#
# Epoch 02994: val_mean_squared_error did not improve from 0.00042
# Epoch 2995/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4073e-04 - val_loss: 0.0133 - val_mean_squared_error: 0.0020
#
# Epoch 02995: val_mean_squared_error did not improve from 0.00042
# Epoch 2996/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.4697e-04 - val_loss: 0.0123 - val_mean_squared_error: 0.0014
#
# Epoch 02996: val_mean_squared_error did not improve from 0.00042
# Epoch 2997/3000
#  - 2s - loss: 0.0105 - mean_squared_error: 3.5919e-04 - val_loss: 0.0201 - val_mean_squared_error: 0.0029
#
# Epoch 02997: val_mean_squared_error did not improve from 0.00042
# Epoch 2998/3000
#  - 2s - loss: 0.0105 - mean_squared_error: 3.1238e-04 - val_loss: 0.0198 - val_mean_squared_error: 0.0030
#
# Epoch 02998: val_mean_squared_error did not improve from 0.00042
# Epoch 2999/3000
#  - 2s - loss: 0.0098 - mean_squared_error: 2.7125e-04 - val_loss: 0.0170 - val_mean_squared_error: 0.0024
#
# Epoch 02999: val_mean_squared_error did not improve from 0.00042
# Epoch 3000/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.7556e-04 - val_loss: 0.0153 - val_mean_squared_error: 0.0022
#
# Epoch 03000: val_mean_squared_error did not improve from 0.00042

# %%
Y_pred = model.predict(X_test)
Y_test = Y_test * 150 + 50
Y_pred = Y_pred * 150 + 50
plt.figure
plt.scatter(Y_test, Y_pred)
Y_error = abs(Y_pred - Y_test)
print('The avarage predict error: ', np.mean(Y_error))
print('The mean squared error:', metrics.mean_squared_error(Y_test, Y_pred))
# Out:
# The avarage predict error:  2.14496392262
# The mean squared error: 36.8344159079

# %%
Y_pred = model.predict(X_train)
Y_train = Y_train * 150 + 50
Y_pred = Y_pred * 150 + 50
plt.figure
plt.scatter(Y_train, Y_pred)
Y_error = abs(Y_pred - Y_train)
print('The avarage predict error: ', np.mean(Y_error))
print('The mean squared error:', metrics.mean_squared_error(Y_train, Y_pred))
# Out:
# The avarage predict error:  0.962058606872
# The mean squared error: 10.4492332958

# %%
# Using the best model
model.load_weights("weights.best1.hdf5")

# %%
Y_pred = model.predict(X_test)
Y_pred = Y_pred * 150 + 50
plt.figure
plt.scatter(Y_test, Y_pred)
Y_error = abs(Y_pred - Y_test)
print('The avarage predict error: ', np.mean(Y_error))
print('The mean squared error:', metrics.mean_squared_error(Y_test, Y_pred))
# Out:
# The avarage predict error:  1.5141794485
# The mean squared error: 11.9097365741

# %%
Y_pred = model.predict(X_train)
#Y_train = Y_train * 150 + 50
Y_pred = Y_pred * 150 + 50
plt.figure
plt.scatter(Y_train, Y_pred)
Y_error = abs(Y_pred - Y_train)
print('The avarage predict error: ', np.mean(Y_error))
print('The mean squared error:', metrics.mean_squared_error(Y_train, Y_pred))
# Out:
# The avarage predict error:  0.815570679201
# The mean squared error: 2.45602250998
