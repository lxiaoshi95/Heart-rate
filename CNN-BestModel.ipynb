# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
import pywt
import timeit
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn import metrics, preprocessing
from scipy import signal
from keras.layers import Dense, Flatten, Activation, TimeDistributed
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import AveragePooling1D
from keras.layers import GlobalMaxPooling1D
from keras.layers import GlobalAveragePooling1D
from keras.utils import np_utils
from keras.optimizers import SGD, Adam, Nadam
from keras.callbacks import ModelCheckpoint
from keras.layers.normalization import BatchNormalization
import keras.callbacks
from keras import initializers, regularizers
from keras.layers.pooling import GlobalAvgPool2D
from keras.layers.recurrent import LSTM
from keras.layers.advanced_activations import LeakyReLU, PReLU
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(42)
dataset = sio.loadmat('dataset_1.mat')
heart_rate = dataset['heart_rate']
heart_rate = (heart_rate - 50) / 150
ss = np.zeros((3203, 1000, 1))
signal = dataset['signal']
ss[:, :, 0] = signal
print(ss.shape)
print(heart_rate.shape)
# Out:
# (3203, 1000, 1)
# (3203, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(ss, heart_rate, test_size=0.2, random_state=222)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (2562, 1000, 1)
# (641, 1000, 1)
# (2562, 1)
# (641, 1)

# %%
# network design
model = Sequential()
# first part
model.add(Conv1D(64, 16, padding='same', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
# second part
model.add(Conv1D(64, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(64, 16, padding='same'))
model.add(MaxPooling1D())
# third layers
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(64, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(64, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(128, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(128, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(128, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(128, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(192, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(192, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(192, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(192, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(256, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(256, 16, padding='same'))
model.add(MaxPooling1D())

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(256, 16, padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Conv1D(256, 16, padding='same'))
model.add(MaxPooling1D())
##
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(Flatten())
model.add(LSTM(units=256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1, activation='sigmoid'))

#model.summary()

# %%
# optimization setup
optm = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=3*10**(-4))
sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)
model.compile(
    loss='mae',
    optimizer=optm,
    metrics=['mse'])

# %%
filepath="weights.best1.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_mean_squared_error', mode='auto', verbose=1, save_best_only=True)
callbacks_list = [checkpoint]

# %%
# training
model.fit(
    X_train, 
    Y_train,
    batch_size=128,
    epochs=3000,
    validation_split=0.2,
    shuffle=True,
    callbacks=callbacks_list,
    verbose=2)
# Out:
# Train on 2049 samples, validate on 513 samples
# Epoch 1/3000
#  - 8s - loss: 0.1569 - mean_squared_error: 0.0369 - val_loss: 0.1744 - val_mean_squared_error: 0.0412
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.04122, saving model to weights.best1.hdf5
# Epoch 2/3000
#  - 2s - loss: 0.1570 - mean_squared_error: 0.0368 - val_loss: 0.1707 - val_mean_squared_error: 0.0403
#
# Epoch 00002: val_mean_squared_error improved from 0.04122 to 0.04032, saving model to weights.best1.hdf5
# Epoch 3/3000
#  - 2s - loss: 0.1576 - mean_squared_error: 0.0368 - val_loss: 0.1672 - val_mean_squared_error: 0.0407
#
# Epoch 00003: val_mean_squared_error did not improve from 0.04032
# Epoch 4/3000
#  - 2s - loss: 0.1570 - mean_squared_error: 0.0390 - val_loss: 0.1706 - val_mean_squared_error: 0.0418
#
# Epoch 00004: val_mean_squared_error did not improve from 0.04032
# Epoch 5/3000
#  - 2s - loss: 0.1579 - mean_squared_error: 0.0374 - val_loss: 0.1699 - val_mean_squared_error: 0.0423
#
# Epoch 00005: val_mean_squared_error did not improve from 0.04032
# Epoch 6/3000
#  - 2s - loss: 0.1568 - mean_squared_error: 0.0385 - val_loss: 0.1699 - val_mean_squared_error: 0.0423
#
# Epoch 00006: val_mean_squared_error did not improve from 0.04032
# Epoch 7/3000
#  - 2s - loss: 0.1560 - mean_squared_error: 0.0387 - val_loss: 0.1704 - val_mean_squared_error: 0.0416
#
# Epoch 00007: val_mean_squared_error did not improve from 0.04032
# Epoch 8/3000
#  - 2s - loss: 0.1562 - mean_squared_error: 0.0371 - val_loss: 0.1690 - val_mean_squared_error: 0.0404
#
# Epoch 00008: val_mean_squared_error did not improve from 0.04032
# Epoch 9/3000
#  - 2s - loss: 0.1561 - mean_squared_error: 0.0364 - val_loss: 0.1685 - val_mean_squared_error: 0.0401
#
# Epoch 00009: val_mean_squared_error improved from 0.04032 to 0.04014, saving model to weights.best1.hdf5
# Epoch 10/3000
#  - 2s - loss: 0.1560 - mean_squared_error: 0.0375 - val_loss: 0.1680 - val_mean_squared_error: 0.0404
#
# Epoch 00010: val_mean_squared_error did not improve from 0.04014
# Epoch 11/3000
#  - 2s - loss: 0.1550 - mean_squared_error: 0.0365 - val_loss: 0.1699 - val_mean_squared_error: 0.0401
#
# Epoch 00011: val_mean_squared_error did not improve from 0.04014
# Epoch 12/3000
#  - 2s - loss: 0.1539 - mean_squared_error: 0.0371 - val_loss: 0.1703 - val_mean_squared_error: 0.0405
#
# Epoch 00012: val_mean_squared_error did not improve from 0.04014
# Epoch 13/3000
#  - 2s - loss: 0.1522 - mean_squared_error: 0.0376 - val_loss: 0.1735 - val_mean_squared_error: 0.0409
#
# Epoch 00013: val_mean_squared_error did not improve from 0.04014
# Epoch 14/3000
#  - 2s - loss: 0.1457 - mean_squared_error: 0.0333 - val_loss: 0.1779 - val_mean_squared_error: 0.0418
#
# Epoch 00014: val_mean_squared_error did not improve from 0.04014
# Epoch 15/3000
#  - 2s - loss: 0.1334 - mean_squared_error: 0.0295 - val_loss: 0.1907 - val_mean_squared_error: 0.0470
#
# Epoch 00015: val_mean_squared_error did not improve from 0.04014
# Epoch 16/3000
#  - 2s - loss: 0.1162 - mean_squared_error: 0.0236 - val_loss: 0.2341 - val_mean_squared_error: 0.0743
#
# Epoch 00016: val_mean_squared_error did not improve from 0.04014
# Epoch 17/3000
#  - 2s - loss: 0.1107 - mean_squared_error: 0.0232 - val_loss: 0.2722 - val_mean_squared_error: 0.1015
#
# Epoch 00017: val_mean_squared_error did not improve from 0.04014
# Epoch 18/3000
#  - 2s - loss: 0.1034 - mean_squared_error: 0.0206 - val_loss: 0.3106 - val_mean_squared_error: 0.1301
#
# Epoch 00018: val_mean_squared_error did not improve from 0.04014
# Epoch 19/3000
#  - 2s - loss: 0.0950 - mean_squared_error: 0.0178 - val_loss: 0.3373 - val_mean_squared_error: 0.1509
#
# Epoch 00019: val_mean_squared_error did not improve from 0.04014
# Epoch 20/3000
#  - 2s - loss: 0.0912 - mean_squared_error: 0.0177 - val_loss: 0.3219 - val_mean_squared_error: 0.1394
#
# Epoch 00020: val_mean_squared_error did not improve from 0.04014
# Epoch 21/3000
#  - 2s - loss: 0.0912 - mean_squared_error: 0.0183 - val_loss: 0.2840 - val_mean_squared_error: 0.1189
#
# Epoch 00021: val_mean_squared_error did not improve from 0.04014
# Epoch 22/3000
#  - 2s - loss: 0.0823 - mean_squared_error: 0.0156 - val_loss: 0.3558 - val_mean_squared_error: 0.1648
#
# Epoch 00022: val_mean_squared_error did not improve from 0.04014
# Epoch 23/3000
#  - 2s - loss: 0.0755 - mean_squared_error: 0.0132 - val_loss: 0.2584 - val_mean_squared_error: 0.1010
#
# Epoch 00023: val_mean_squared_error did not improve from 0.04014
# Epoch 24/3000
#  - 2s - loss: 0.0815 - mean_squared_error: 0.0159 - val_loss: 0.2819 - val_mean_squared_error: 0.1142
#
# Epoch 00024: val_mean_squared_error did not improve from 0.04014
# Epoch 25/3000
#  - 2s - loss: 0.0706 - mean_squared_error: 0.0123 - val_loss: 0.2829 - val_mean_squared_error: 0.1179
#
# Epoch 00025: val_mean_squared_error did not improve from 0.04014
# Epoch 26/3000
#  - 2s - loss: 0.0665 - mean_squared_error: 0.0109 - val_loss: 0.2330 - val_mean_squared_error: 0.0924
#
# Epoch 00026: val_mean_squared_error did not improve from 0.04014
# Epoch 27/3000
#  - 2s - loss: 0.0681 - mean_squared_error: 0.0116 - val_loss: 0.1768 - val_mean_squared_error: 0.0607
#
# Epoch 00027: val_mean_squared_error did not improve from 0.04014
# Epoch 28/3000
#  - 2s - loss: 0.0639 - mean_squared_error: 0.0111 - val_loss: 0.1222 - val_mean_squared_error: 0.0336
#
# Epoch 00028: val_mean_squared_error improved from 0.04014 to 0.03359, saving model to weights.best1.hdf5
# Epoch 29/3000
#  - 2s - loss: 0.0604 - mean_squared_error: 0.0102 - val_loss: 0.1570 - val_mean_squared_error: 0.0525
#
# Epoch 00029: val_mean_squared_error did not improve from 0.03359
# Epoch 30/3000
#  - 2s - loss: 0.0558 - mean_squared_error: 0.0088 - val_loss: 0.0804 - val_mean_squared_error: 0.0196
#
# Epoch 00030: val_mean_squared_error improved from 0.03359 to 0.01959, saving model to weights.best1.hdf5
# Epoch 31/3000
#  - 2s - loss: 0.0576 - mean_squared_error: 0.0099 - val_loss: 0.1623 - val_mean_squared_error: 0.0547
#
# Epoch 00031: val_mean_squared_error did not improve from 0.01959
# Epoch 32/3000
#  - 2s - loss: 0.0536 - mean_squared_error: 0.0086 - val_loss: 0.0829 - val_mean_squared_error: 0.0198
#
# Epoch 00032: val_mean_squared_error did not improve from 0.01959
# Epoch 33/3000
#  - 2s - loss: 0.0511 - mean_squared_error: 0.0080 - val_loss: 0.0752 - val_mean_squared_error: 0.0194
#
# Epoch 00033: val_mean_squared_error improved from 0.01959 to 0.01940, saving model to weights.best1.hdf5
# Epoch 34/3000
#  - 2s - loss: 0.0509 - mean_squared_error: 0.0078 - val_loss: 0.1253 - val_mean_squared_error: 0.0373
#
# Epoch 00034: val_mean_squared_error did not improve from 0.01940
# Epoch 35/3000
#  - 2s - loss: 0.0503 - mean_squared_error: 0.0075 - val_loss: 0.0664 - val_mean_squared_error: 0.0172
#
# Epoch 00035: val_mean_squared_error improved from 0.01940 to 0.01717, saving model to weights.best1.hdf5
# Epoch 36/3000
#  - 2s - loss: 0.0492 - mean_squared_error: 0.0076 - val_loss: 0.0694 - val_mean_squared_error: 0.0150
#
# Epoch 00036: val_mean_squared_error improved from 0.01717 to 0.01499, saving model to weights.best1.hdf5
# Epoch 37/3000
#  - 2s - loss: 0.0489 - mean_squared_error: 0.0084 - val_loss: 0.0773 - val_mean_squared_error: 0.0154
#
# Epoch 00037: val_mean_squared_error did not improve from 0.01499
# Epoch 38/3000
#  - 2s - loss: 0.0477 - mean_squared_error: 0.0070 - val_loss: 0.0638 - val_mean_squared_error: 0.0112
#
# Epoch 00038: val_mean_squared_error improved from 0.01499 to 0.01118, saving model to weights.best1.hdf5
# Epoch 39/3000
#  - 2s - loss: 0.0413 - mean_squared_error: 0.0053 - val_loss: 0.1015 - val_mean_squared_error: 0.0287
#
# Epoch 00039: val_mean_squared_error did not improve from 0.01118
# Epoch 40/3000
#  - 2s - loss: 0.0385 - mean_squared_error: 0.0049 - val_loss: 0.0577 - val_mean_squared_error: 0.0110
#
# Epoch 00040: val_mean_squared_error improved from 0.01118 to 0.01102, saving model to weights.best1.hdf5
# Epoch 41/3000
#  - 2s - loss: 0.0418 - mean_squared_error: 0.0056 - val_loss: 0.0641 - val_mean_squared_error: 0.0121
#
# Epoch 00041: val_mean_squared_error did not improve from 0.01102
# Epoch 42/3000
#  - 2s - loss: 0.0389 - mean_squared_error: 0.0043 - val_loss: 0.0650 - val_mean_squared_error: 0.0118
#
# Epoch 00042: val_mean_squared_error did not improve from 0.01102
# Epoch 43/3000
#  - 2s - loss: 0.0435 - mean_squared_error: 0.0066 - val_loss: 0.0499 - val_mean_squared_error: 0.0076
#
# Epoch 00043: val_mean_squared_error improved from 0.01102 to 0.00756, saving model to weights.best1.hdf5
# Epoch 44/3000
#  - 2s - loss: 0.0406 - mean_squared_error: 0.0052 - val_loss: 0.1047 - val_mean_squared_error: 0.0284
#
# Epoch 00044: val_mean_squared_error did not improve from 0.00756
# Epoch 45/3000
#  - 2s - loss: 0.0409 - mean_squared_error: 0.0059 - val_loss: 0.0808 - val_mean_squared_error: 0.0244
#
# Epoch 00045: val_mean_squared_error did not improve from 0.00756
# Epoch 46/3000
#  - 2s - loss: 0.0410 - mean_squared_error: 0.0056 - val_loss: 0.0613 - val_mean_squared_error: 0.0132
#
# Epoch 00046: val_mean_squared_error did not improve from 0.00756
# Epoch 47/3000
#  - 2s - loss: 0.0431 - mean_squared_error: 0.0067 - val_loss: 0.0849 - val_mean_squared_error: 0.0220
#
# Epoch 00047: val_mean_squared_error did not improve from 0.00756
# Epoch 48/3000
#  - 2s - loss: 0.0404 - mean_squared_error: 0.0062 - val_loss: 0.0493 - val_mean_squared_error: 0.0093
#
# Epoch 00048: val_mean_squared_error did not improve from 0.00756
# Epoch 49/3000
#  - 2s - loss: 0.0411 - mean_squared_error: 0.0064 - val_loss: 0.0776 - val_mean_squared_error: 0.0167
#
# Epoch 00049: val_mean_squared_error did not improve from 0.00756
# Epoch 50/3000
#  - 2s - loss: 0.0395 - mean_squared_error: 0.0051 - val_loss: 0.0771 - val_mean_squared_error: 0.0217
#
# Epoch 00050: val_mean_squared_error did not improve from 0.00756
# Epoch 51/3000
#  - 2s - loss: 0.0359 - mean_squared_error: 0.0038 - val_loss: 0.0809 - val_mean_squared_error: 0.0236
#
# Epoch 00051: val_mean_squared_error did not improve from 0.00756
# Epoch 52/3000
#  - 2s - loss: 0.0366 - mean_squared_error: 0.0043 - val_loss: 0.0670 - val_mean_squared_error: 0.0158
#
# Epoch 00052: val_mean_squared_error did not improve from 0.00756
# Epoch 53/3000
#  - 2s - loss: 0.0355 - mean_squared_error: 0.0037 - val_loss: 0.0636 - val_mean_squared_error: 0.0142
#
# Epoch 00053: val_mean_squared_error did not improve from 0.00756
# Epoch 54/3000
#  - 2s - loss: 0.0323 - mean_squared_error: 0.0038 - val_loss: 0.0843 - val_mean_squared_error: 0.0243
#
# Epoch 00054: val_mean_squared_error did not improve from 0.00756
# Epoch 55/3000
#  - 2s - loss: 0.0308 - mean_squared_error: 0.0029 - val_loss: 0.0559 - val_mean_squared_error: 0.0127
#
# Epoch 00055: val_mean_squared_error did not improve from 0.00756
# Epoch 56/3000
#  - 2s - loss: 0.0306 - mean_squared_error: 0.0031 - val_loss: 0.0735 - val_mean_squared_error: 0.0182
#
# Epoch 00056: val_mean_squared_error did not improve from 0.00756
# Epoch 57/3000
#  - 2s - loss: 0.0298 - mean_squared_error: 0.0025 - val_loss: 0.0751 - val_mean_squared_error: 0.0203
#
# Epoch 00057: val_mean_squared_error did not improve from 0.00756
# Epoch 58/3000
#  - 2s - loss: 0.0297 - mean_squared_error: 0.0030 - val_loss: 0.0899 - val_mean_squared_error: 0.0293
#
# Epoch 00058: val_mean_squared_error did not improve from 0.00756
# Epoch 59/3000
#  - 2s - loss: 0.0320 - mean_squared_error: 0.0041 - val_loss: 0.0513 - val_mean_squared_error: 0.0106
#
# Epoch 00059: val_mean_squared_error did not improve from 0.00756
# Epoch 60/3000
#  - 2s - loss: 0.0301 - mean_squared_error: 0.0030 - val_loss: 0.0398 - val_mean_squared_error: 0.0067
#
# Epoch 00060: val_mean_squared_error improved from 0.00756 to 0.00672, saving model to weights.best1.hdf5
# Epoch 61/3000
#  - 2s - loss: 0.0295 - mean_squared_error: 0.0029 - val_loss: 0.0318 - val_mean_squared_error: 0.0046
#
# Epoch 00061: val_mean_squared_error improved from 0.00672 to 0.00458, saving model to weights.best1.hdf5
# Epoch 62/3000
#  - 2s - loss: 0.0303 - mean_squared_error: 0.0032 - val_loss: 0.0336 - val_mean_squared_error: 0.0053
#
# Epoch 00062: val_mean_squared_error did not improve from 0.00458
# Epoch 63/3000
#  - 2s - loss: 0.0284 - mean_squared_error: 0.0025 - val_loss: 0.0326 - val_mean_squared_error: 0.0051
#
# Epoch 00063: val_mean_squared_error did not improve from 0.00458
# Epoch 64/3000
#  - 2s - loss: 0.0291 - mean_squared_error: 0.0029 - val_loss: 0.0595 - val_mean_squared_error: 0.0157
#
# Epoch 00064: val_mean_squared_error did not improve from 0.00458
# Epoch 65/3000
#  - 2s - loss: 0.0242 - mean_squared_error: 0.0019 - val_loss: 0.0399 - val_mean_squared_error: 0.0071
#
# Epoch 00065: val_mean_squared_error did not improve from 0.00458
# Epoch 66/3000
#  - 2s - loss: 0.0257 - mean_squared_error: 0.0018 - val_loss: 0.0612 - val_mean_squared_error: 0.0149
#
# Epoch 00066: val_mean_squared_error did not improve from 0.00458
# Epoch 67/3000
#  - 2s - loss: 0.0241 - mean_squared_error: 0.0019 - val_loss: 0.0778 - val_mean_squared_error: 0.0224
#
# Epoch 00067: val_mean_squared_error did not improve from 0.00458
# Epoch 68/3000
#  - 2s - loss: 0.0255 - mean_squared_error: 0.0019 - val_loss: 0.0635 - val_mean_squared_error: 0.0170
#
# Epoch 00068: val_mean_squared_error did not improve from 0.00458
# Epoch 69/3000
#  - 2s - loss: 0.0265 - mean_squared_error: 0.0023 - val_loss: 0.0288 - val_mean_squared_error: 0.0037
#
# Epoch 00069: val_mean_squared_error improved from 0.00458 to 0.00365, saving model to weights.best1.hdf5
# Epoch 70/3000
#  - 2s - loss: 0.0242 - mean_squared_error: 0.0017 - val_loss: 0.0324 - val_mean_squared_error: 0.0047
#
# Epoch 00070: val_mean_squared_error did not improve from 0.00365
# Epoch 71/3000
#  - 2s - loss: 0.0235 - mean_squared_error: 0.0019 - val_loss: 0.0324 - val_mean_squared_error: 0.0047
#
# Epoch 00071: val_mean_squared_error did not improve from 0.00365
# Epoch 72/3000
#  - 2s - loss: 0.0253 - mean_squared_error: 0.0020 - val_loss: 0.0453 - val_mean_squared_error: 0.0091
#
# Epoch 00072: val_mean_squared_error did not improve from 0.00365
# Epoch 73/3000
#  - 2s - loss: 0.0232 - mean_squared_error: 0.0015 - val_loss: 0.0864 - val_mean_squared_error: 0.0274
#
# Epoch 00073: val_mean_squared_error did not improve from 0.00365
# Epoch 74/3000
#  - 2s - loss: 0.0227 - mean_squared_error: 0.0018 - val_loss: 0.0449 - val_mean_squared_error: 0.0108
#
# Epoch 00074: val_mean_squared_error did not improve from 0.00365
# Epoch 75/3000
#  - 2s - loss: 0.0233 - mean_squared_error: 0.0018 - val_loss: 0.0325 - val_mean_squared_error: 0.0049
#
# Epoch 00075: val_mean_squared_error did not improve from 0.00365
# Epoch 76/3000
#  - 2s - loss: 0.0220 - mean_squared_error: 0.0012 - val_loss: 0.0327 - val_mean_squared_error: 0.0054
#
# Epoch 00076: val_mean_squared_error did not improve from 0.00365
# Epoch 77/3000
#  - 2s - loss: 0.0215 - mean_squared_error: 0.0013 - val_loss: 0.0360 - val_mean_squared_error: 0.0064
#
# Epoch 00077: val_mean_squared_error did not improve from 0.00365
# Epoch 78/3000
#  - 2s - loss: 0.0209 - mean_squared_error: 0.0012 - val_loss: 0.0866 - val_mean_squared_error: 0.0301
#
# Epoch 00078: val_mean_squared_error did not improve from 0.00365
# Epoch 79/3000
#  - 2s - loss: 0.0219 - mean_squared_error: 0.0013 - val_loss: 0.0591 - val_mean_squared_error: 0.0169
#
# Epoch 00079: val_mean_squared_error did not improve from 0.00365
# Epoch 80/3000
#  - 2s - loss: 0.0208 - mean_squared_error: 0.0013 - val_loss: 0.0467 - val_mean_squared_error: 0.0118
#
# Epoch 00080: val_mean_squared_error did not improve from 0.00365
# Epoch 81/3000
#  - 2s - loss: 0.0219 - mean_squared_error: 0.0013 - val_loss: 0.0492 - val_mean_squared_error: 0.0121
#
# Epoch 00081: val_mean_squared_error did not improve from 0.00365
# Epoch 82/3000
#  - 2s - loss: 0.0235 - mean_squared_error: 0.0020 - val_loss: 0.0422 - val_mean_squared_error: 0.0088
#
# Epoch 00082: val_mean_squared_error did not improve from 0.00365
# Epoch 83/3000
#  - 2s - loss: 0.0217 - mean_squared_error: 0.0014 - val_loss: 0.0274 - val_mean_squared_error: 0.0042
#
# Epoch 00083: val_mean_squared_error did not improve from 0.00365
# Epoch 84/3000
#  - 2s - loss: 0.0240 - mean_squared_error: 0.0019 - val_loss: 0.0434 - val_mean_squared_error: 0.0098
#
# Epoch 00084: val_mean_squared_error did not improve from 0.00365
# Epoch 85/3000
#  - 2s - loss: 0.0253 - mean_squared_error: 0.0022 - val_loss: 0.0621 - val_mean_squared_error: 0.0160
#
# Epoch 00085: val_mean_squared_error did not improve from 0.00365
# Epoch 86/3000
#  - 2s - loss: 0.0271 - mean_squared_error: 0.0023 - val_loss: 0.0871 - val_mean_squared_error: 0.0269
#
# Epoch 00086: val_mean_squared_error did not improve from 0.00365
# Epoch 87/3000
#  - 2s - loss: 0.0235 - mean_squared_error: 0.0018 - val_loss: 0.0389 - val_mean_squared_error: 0.0073
#
# Epoch 00087: val_mean_squared_error did not improve from 0.00365
# Epoch 88/3000
#  - 2s - loss: 0.0226 - mean_squared_error: 0.0017 - val_loss: 0.0314 - val_mean_squared_error: 0.0056
#
# Epoch 00088: val_mean_squared_error did not improve from 0.00365
# Epoch 89/3000
#  - 2s - loss: 0.0211 - mean_squared_error: 0.0012 - val_loss: 0.0343 - val_mean_squared_error: 0.0065
#
# Epoch 00089: val_mean_squared_error did not improve from 0.00365
# Epoch 90/3000
#  - 2s - loss: 0.0192 - mean_squared_error: 0.0010 - val_loss: 0.0265 - val_mean_squared_error: 0.0043
#
# Epoch 00090: val_mean_squared_error did not improve from 0.00365
# Epoch 91/3000
#  - 2s - loss: 0.0192 - mean_squared_error: 0.0010 - val_loss: 0.0277 - val_mean_squared_error: 0.0041
#
# Epoch 00091: val_mean_squared_error did not improve from 0.00365
# Epoch 92/3000
#  - 2s - loss: 0.0183 - mean_squared_error: 6.9447e-04 - val_loss: 0.0319 - val_mean_squared_error: 0.0058
#
# Epoch 00092: val_mean_squared_error did not improve from 0.00365
# Epoch 93/3000
#  - 2s - loss: 0.0204 - mean_squared_error: 0.0011 - val_loss: 0.0255 - val_mean_squared_error: 0.0038
#
# Epoch 00093: val_mean_squared_error did not improve from 0.00365
# Epoch 94/3000
#  - 2s - loss: 0.0222 - mean_squared_error: 0.0016 - val_loss: 0.0337 - val_mean_squared_error: 0.0065
#
# Epoch 00094: val_mean_squared_error did not improve from 0.00365
# Epoch 95/3000
#  - 2s - loss: 0.0200 - mean_squared_error: 0.0014 - val_loss: 0.0258 - val_mean_squared_error: 0.0029
#
# Epoch 00095: val_mean_squared_error improved from 0.00365 to 0.00289, saving model to weights.best1.hdf5
# Epoch 96/3000
#  - 2s - loss: 0.0200 - mean_squared_error: 0.0015 - val_loss: 0.0291 - val_mean_squared_error: 0.0056
#
# Epoch 00096: val_mean_squared_error did not improve from 0.00289
# Epoch 97/3000
#  - 2s - loss: 0.0221 - mean_squared_error: 0.0020 - val_loss: 0.0698 - val_mean_squared_error: 0.0217
#
# Epoch 00097: val_mean_squared_error did not improve from 0.00289
# Epoch 98/3000
#  - 2s - loss: 0.0206 - mean_squared_error: 0.0014 - val_loss: 0.0334 - val_mean_squared_error: 0.0059
#
# Epoch 00098: val_mean_squared_error did not improve from 0.00289
# Epoch 99/3000
#  - 2s - loss: 0.0204 - mean_squared_error: 0.0013 - val_loss: 0.0387 - val_mean_squared_error: 0.0077
#
# Epoch 00099: val_mean_squared_error did not improve from 0.00289
# Epoch 100/3000
#  - 2s - loss: 0.0185 - mean_squared_error: 9.1607e-04 - val_loss: 0.0281 - val_mean_squared_error: 0.0042
#
# Epoch 00100: val_mean_squared_error did not improve from 0.00289
# Epoch 101/3000
#  - 2s - loss: 0.0182 - mean_squared_error: 9.0118e-04 - val_loss: 0.0227 - val_mean_squared_error: 0.0030
#
# Epoch 00101: val_mean_squared_error did not improve from 0.00289
# Epoch 102/3000
#  - 2s - loss: 0.0180 - mean_squared_error: 9.3619e-04 - val_loss: 0.0272 - val_mean_squared_error: 0.0033
#
# Epoch 00102: val_mean_squared_error did not improve from 0.00289
# Epoch 103/3000
#  - 2s - loss: 0.0175 - mean_squared_error: 8.2165e-04 - val_loss: 0.0458 - val_mean_squared_error: 0.0090
#
# Epoch 00103: val_mean_squared_error did not improve from 0.00289
# Epoch 104/3000
#  - 2s - loss: 0.0187 - mean_squared_error: 7.3961e-04 - val_loss: 0.0462 - val_mean_squared_error: 0.0095
#
# Epoch 00104: val_mean_squared_error did not improve from 0.00289
# Epoch 105/3000
#  - 2s - loss: 0.0198 - mean_squared_error: 9.4255e-04 - val_loss: 0.0307 - val_mean_squared_error: 0.0051
#
# Epoch 00105: val_mean_squared_error did not improve from 0.00289
# Epoch 106/3000
#  - 2s - loss: 0.0191 - mean_squared_error: 0.0010 - val_loss: 0.0221 - val_mean_squared_error: 0.0017
#
# Epoch 00106: val_mean_squared_error improved from 0.00289 to 0.00165, saving model to weights.best1.hdf5
# Epoch 107/3000
#  - 2s - loss: 0.0182 - mean_squared_error: 9.0896e-04 - val_loss: 0.0251 - val_mean_squared_error: 0.0023
#
# Epoch 00107: val_mean_squared_error did not improve from 0.00165
# Epoch 108/3000
#  - 2s - loss: 0.0174 - mean_squared_error: 6.6432e-04 - val_loss: 0.0245 - val_mean_squared_error: 0.0031
#
# Epoch 00108: val_mean_squared_error did not improve from 0.00165
# Epoch 109/3000
#  - 2s - loss: 0.0177 - mean_squared_error: 8.8969e-04 - val_loss: 0.0282 - val_mean_squared_error: 0.0036
#
# Epoch 00109: val_mean_squared_error did not improve from 0.00165
# Epoch 110/3000
#  - 2s - loss: 0.0165 - mean_squared_error: 6.6290e-04 - val_loss: 0.0257 - val_mean_squared_error: 0.0031
#
# Epoch 00110: val_mean_squared_error did not improve from 0.00165
# Epoch 111/3000
#  - 2s - loss: 0.0192 - mean_squared_error: 0.0012 - val_loss: 0.0226 - val_mean_squared_error: 0.0028
#
# Epoch 00111: val_mean_squared_error did not improve from 0.00165
# Epoch 112/3000
#  - 2s - loss: 0.0178 - mean_squared_error: 8.9941e-04 - val_loss: 0.0211 - val_mean_squared_error: 0.0026
#
# Epoch 00112: val_mean_squared_error did not improve from 0.00165
# Epoch 113/3000
#  - 2s - loss: 0.0170 - mean_squared_error: 7.8047e-04 - val_loss: 0.0405 - val_mean_squared_error: 0.0111
#
# Epoch 00113: val_mean_squared_error did not improve from 0.00165
# Epoch 114/3000
#  - 2s - loss: 0.0176 - mean_squared_error: 9.4300e-04 - val_loss: 0.0212 - val_mean_squared_error: 0.0021
#
# Epoch 00114: val_mean_squared_error did not improve from 0.00165
# Epoch 115/3000
#  - 2s - loss: 0.0174 - mean_squared_error: 9.6697e-04 - val_loss: 0.0404 - val_mean_squared_error: 0.0079
#
# Epoch 00115: val_mean_squared_error did not improve from 0.00165
# Epoch 116/3000
#  - 2s - loss: 0.0199 - mean_squared_error: 0.0014 - val_loss: 0.0265 - val_mean_squared_error: 0.0040
#
# Epoch 00116: val_mean_squared_error did not improve from 0.00165
# Epoch 117/3000
#  - 2s - loss: 0.0173 - mean_squared_error: 8.0979e-04 - val_loss: 0.0295 - val_mean_squared_error: 0.0043
#
# Epoch 00117: val_mean_squared_error did not improve from 0.00165
# Epoch 118/3000
#  - 2s - loss: 0.0181 - mean_squared_error: 9.3490e-04 - val_loss: 0.0230 - val_mean_squared_error: 0.0031
#
# Epoch 00118: val_mean_squared_error did not improve from 0.00165
# Epoch 119/3000
#  - 2s - loss: 0.0165 - mean_squared_error: 6.0330e-04 - val_loss: 0.0271 - val_mean_squared_error: 0.0036
#
# Epoch 00119: val_mean_squared_error did not improve from 0.00165
# Epoch 120/3000
#  - 2s - loss: 0.0166 - mean_squared_error: 6.0779e-04 - val_loss: 0.0204 - val_mean_squared_error: 0.0019
#
# Epoch 00120: val_mean_squared_error did not improve from 0.00165
# Epoch 121/3000
#  - 2s - loss: 0.0173 - mean_squared_error: 8.5147e-04 - val_loss: 0.0222 - val_mean_squared_error: 0.0033
#
# Epoch 00121: val_mean_squared_error did not improve from 0.00165
# Epoch 122/3000
#  - 2s - loss: 0.0169 - mean_squared_error: 8.9202e-04 - val_loss: 0.0260 - val_mean_squared_error: 0.0031
#
# Epoch 00122: val_mean_squared_error did not improve from 0.00165
# Epoch 123/3000
#  - 2s - loss: 0.0171 - mean_squared_error: 6.6967e-04 - val_loss: 0.0284 - val_mean_squared_error: 0.0048
#
# Epoch 00123: val_mean_squared_error did not improve from 0.00165
# Epoch 124/3000
#  - 2s - loss: 0.0170 - mean_squared_error: 7.1313e-04 - val_loss: 0.0232 - val_mean_squared_error: 0.0033
#
# Epoch 00124: val_mean_squared_error did not improve from 0.00165
# Epoch 125/3000
#  - 2s - loss: 0.0159 - mean_squared_error: 6.1189e-04 - val_loss: 0.0248 - val_mean_squared_error: 0.0043
#
# Epoch 00125: val_mean_squared_error did not improve from 0.00165
# Epoch 126/3000
#  - 2s - loss: 0.0160 - mean_squared_error: 7.0800e-04 - val_loss: 0.0287 - val_mean_squared_error: 0.0040
#
# Epoch 00126: val_mean_squared_error did not improve from 0.00165
# Epoch 127/3000
#  - 2s - loss: 0.0165 - mean_squared_error: 7.9898e-04 - val_loss: 0.0423 - val_mean_squared_error: 0.0100
#
# Epoch 00127: val_mean_squared_error did not improve from 0.00165
# Epoch 128/3000
#  - 2s - loss: 0.0166 - mean_squared_error: 8.6868e-04 - val_loss: 0.0303 - val_mean_squared_error: 0.0048
#
# Epoch 00128: val_mean_squared_error did not improve from 0.00165
# Epoch 129/3000
#  - 2s - loss: 0.0169 - mean_squared_error: 7.8138e-04 - val_loss: 0.0305 - val_mean_squared_error: 0.0055
#
# Epoch 00129: val_mean_squared_error did not improve from 0.00165
# Epoch 130/3000
#  - 2s - loss: 0.0170 - mean_squared_error: 8.8382e-04 - val_loss: 0.0238 - val_mean_squared_error: 0.0035
#
# Epoch 00130: val_mean_squared_error did not improve from 0.00165
# Epoch 131/3000
#  - 2s - loss: 0.0163 - mean_squared_error: 7.3924e-04 - val_loss: 0.0245 - val_mean_squared_error: 0.0028
#
# Epoch 00131: val_mean_squared_error did not improve from 0.00165
# Epoch 132/3000
#  - 2s - loss: 0.0158 - mean_squared_error: 6.5012e-04 - val_loss: 0.0208 - val_mean_squared_error: 0.0019
#
# Epoch 00132: val_mean_squared_error did not improve from 0.00165
# Epoch 133/3000
#  - 2s - loss: 0.0150 - mean_squared_error: 5.7888e-04 - val_loss: 0.0182 - val_mean_squared_error: 0.0016
#
# Epoch 00133: val_mean_squared_error improved from 0.00165 to 0.00158, saving model to weights.best1.hdf5
# Epoch 134/3000
#  - 2s - loss: 0.0168 - mean_squared_error: 7.7554e-04 - val_loss: 0.0210 - val_mean_squared_error: 0.0019
#
# Epoch 00134: val_mean_squared_error did not improve from 0.00158
# Epoch 135/3000
#  - 2s - loss: 0.0175 - mean_squared_error: 0.0011 - val_loss: 0.0296 - val_mean_squared_error: 0.0056
#
# Epoch 00135: val_mean_squared_error did not improve from 0.00158
# Epoch 136/3000
#  - 2s - loss: 0.0180 - mean_squared_error: 0.0010 - val_loss: 0.0374 - val_mean_squared_error: 0.0064
#
# Epoch 00136: val_mean_squared_error did not improve from 0.00158
# Epoch 137/3000
#  - 2s - loss: 0.0198 - mean_squared_error: 0.0018 - val_loss: 0.0434 - val_mean_squared_error: 0.0082
#
# Epoch 00137: val_mean_squared_error did not improve from 0.00158
# Epoch 138/3000
#  - 2s - loss: 0.0177 - mean_squared_error: 0.0011 - val_loss: 0.0321 - val_mean_squared_error: 0.0051
#
# Epoch 00138: val_mean_squared_error did not improve from 0.00158
# Epoch 139/3000
#  - 2s - loss: 0.0159 - mean_squared_error: 7.0617e-04 - val_loss: 0.0311 - val_mean_squared_error: 0.0046
#
# Epoch 00139: val_mean_squared_error did not improve from 0.00158
# Epoch 140/3000
#  - 2s - loss: 0.0160 - mean_squared_error: 5.4947e-04 - val_loss: 0.0248 - val_mean_squared_error: 0.0036
#
# Epoch 00140: val_mean_squared_error did not improve from 0.00158
# Epoch 141/3000
#  - 2s - loss: 0.0158 - mean_squared_error: 6.8051e-04 - val_loss: 0.0268 - val_mean_squared_error: 0.0040
#
# Epoch 00141: val_mean_squared_error did not improve from 0.00158
# Epoch 142/3000
#  - 2s - loss: 0.0153 - mean_squared_error: 5.2782e-04 - val_loss: 0.0291 - val_mean_squared_error: 0.0058
#
# Epoch 00142: val_mean_squared_error did not improve from 0.00158
# Epoch 143/3000
#  - 2s - loss: 0.0162 - mean_squared_error: 7.6970e-04 - val_loss: 0.0302 - val_mean_squared_error: 0.0050
#
# Epoch 00143: val_mean_squared_error did not improve from 0.00158
# Epoch 144/3000
#  - 2s - loss: 0.0189 - mean_squared_error: 0.0019 - val_loss: 0.0211 - val_mean_squared_error: 0.0026
#
# Epoch 00144: val_mean_squared_error did not improve from 0.00158
# Epoch 145/3000
#  - 2s - loss: 0.0150 - mean_squared_error: 5.6141e-04 - val_loss: 0.0240 - val_mean_squared_error: 0.0036
#
# Epoch 00145: val_mean_squared_error did not improve from 0.00158
# Epoch 146/3000
#  - 2s - loss: 0.0167 - mean_squared_error: 9.0840e-04 - val_loss: 0.0222 - val_mean_squared_error: 0.0027
#
# Epoch 00146: val_mean_squared_error did not improve from 0.00158
# Epoch 147/3000
#  - 2s - loss: 0.0164 - mean_squared_error: 7.6970e-04 - val_loss: 0.0268 - val_mean_squared_error: 0.0034
#
# Epoch 00147: val_mean_squared_error did not improve from 0.00158
# Epoch 148/3000
#  - 2s - loss: 0.0154 - mean_squared_error: 6.1047e-04 - val_loss: 0.0479 - val_mean_squared_error: 0.0132
#
# Epoch 00148: val_mean_squared_error did not improve from 0.00158
# Epoch 149/3000
#  - 2s - loss: 0.0148 - mean_squared_error: 6.2855e-04 - val_loss: 0.0301 - val_mean_squared_error: 0.0064
#
# Epoch 00149: val_mean_squared_error did not improve from 0.00158
# Epoch 150/3000
#  - 2s - loss: 0.0155 - mean_squared_error: 7.5598e-04 - val_loss: 0.0745 - val_mean_squared_error: 0.0246
#
# Epoch 00150: val_mean_squared_error did not improve from 0.00158
# Epoch 151/3000
#  - 2s - loss: 0.0166 - mean_squared_error: 0.0013 - val_loss: 0.0400 - val_mean_squared_error: 0.0100
#
# Epoch 00151: val_mean_squared_error did not improve from 0.00158
# Epoch 152/3000
#  - 2s - loss: 0.0151 - mean_squared_error: 5.9567e-04 - val_loss: 0.0317 - val_mean_squared_error: 0.0060
#
# Epoch 00152: val_mean_squared_error did not improve from 0.00158
# Epoch 153/3000
#  - 2s - loss: 0.0154 - mean_squared_error: 5.7888e-04 - val_loss: 0.0319 - val_mean_squared_error: 0.0074
#
# Epoch 00153: val_mean_squared_error did not improve from 0.00158
# Epoch 154/3000
#  - 2s - loss: 0.0146 - mean_squared_error: 4.8627e-04 - val_loss: 0.0224 - val_mean_squared_error: 0.0033
#
# Epoch 00154: val_mean_squared_error did not improve from 0.00158
# Epoch 155/3000
#  - 2s - loss: 0.0141 - mean_squared_error: 4.9973e-04 - val_loss: 0.0212 - val_mean_squared_error: 0.0038
#
# Epoch 00155: val_mean_squared_error did not improve from 0.00158
# Epoch 156/3000
#  - 2s - loss: 0.0153 - mean_squared_error: 5.5554e-04 - val_loss: 0.0212 - val_mean_squared_error: 0.0030
#
# Epoch 00156: val_mean_squared_error did not improve from 0.00158
# Epoch 157/3000
#  - 2s - loss: 0.0147 - mean_squared_error: 5.2979e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0013
#
# Epoch 00157: val_mean_squared_error improved from 0.00158 to 0.00133, saving model to weights.best1.hdf5
# Epoch 158/3000
#  - 2s - loss: 0.0136 - mean_squared_error: 4.1122e-04 - val_loss: 0.0165 - val_mean_squared_error: 8.9596e-04
#
# Epoch 00158: val_mean_squared_error improved from 0.00133 to 0.00090, saving model to weights.best1.hdf5
# Epoch 159/3000
#  - 2s - loss: 0.0159 - mean_squared_error: 8.4995e-04 - val_loss: 0.0186 - val_mean_squared_error: 0.0021
#
# Epoch 00159: val_mean_squared_error did not improve from 0.00090
# Epoch 160/3000
#  - 2s - loss: 0.0147 - mean_squared_error: 4.5224e-04 - val_loss: 0.0180 - val_mean_squared_error: 0.0023
#
# Epoch 00160: val_mean_squared_error did not improve from 0.00090
# Epoch 161/3000
#  - 2s - loss: 0.0145 - mean_squared_error: 5.6496e-04 - val_loss: 0.0235 - val_mean_squared_error: 0.0036
#
# Epoch 00161: val_mean_squared_error did not improve from 0.00090
# Epoch 162/3000
#  - 2s - loss: 0.0152 - mean_squared_error: 5.3744e-04 - val_loss: 0.0186 - val_mean_squared_error: 0.0017
#
# Epoch 00162: val_mean_squared_error did not improve from 0.00090
# Epoch 163/3000
#  - 2s - loss: 0.0139 - mean_squared_error: 4.3020e-04 - val_loss: 0.0187 - val_mean_squared_error: 0.0023
#
# Epoch 00163: val_mean_squared_error did not improve from 0.00090
# Epoch 164/3000
#  - 2s - loss: 0.0145 - mean_squared_error: 5.2958e-04 - val_loss: 0.0147 - val_mean_squared_error: 9.5613e-04
#
# Epoch 00164: val_mean_squared_error did not improve from 0.00090
# Epoch 165/3000
#  - 2s - loss: 0.0140 - mean_squared_error: 6.1886e-04 - val_loss: 0.0142 - val_mean_squared_error: 9.6914e-04
#
# Epoch 00165: val_mean_squared_error did not improve from 0.00090
# Epoch 166/3000
#  - 2s - loss: 0.0139 - mean_squared_error: 5.3615e-04 - val_loss: 0.0167 - val_mean_squared_error: 0.0013
#
# Epoch 00166: val_mean_squared_error did not improve from 0.00090
# Epoch 167/3000
#  - 2s - loss: 0.0140 - mean_squared_error: 4.4646e-04 - val_loss: 0.0152 - val_mean_squared_error: 0.0012
#
# Epoch 00167: val_mean_squared_error did not improve from 0.00090
# Epoch 168/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 3.7388e-04 - val_loss: 0.0166 - val_mean_squared_error: 0.0012
#
# Epoch 00168: val_mean_squared_error did not improve from 0.00090
# Epoch 169/3000
#  - 2s - loss: 0.0142 - mean_squared_error: 5.0933e-04 - val_loss: 0.0194 - val_mean_squared_error: 0.0016
#
# Epoch 00169: val_mean_squared_error did not improve from 0.00090
# Epoch 170/3000
#  - 2s - loss: 0.0146 - mean_squared_error: 4.1731e-04 - val_loss: 0.0155 - val_mean_squared_error: 0.0012
#
# Epoch 00170: val_mean_squared_error did not improve from 0.00090
# Epoch 171/3000
#  - 2s - loss: 0.0138 - mean_squared_error: 3.5399e-04 - val_loss: 0.0159 - val_mean_squared_error: 0.0013
#
# Epoch 00171: val_mean_squared_error did not improve from 0.00090
# Epoch 172/3000
#  - 2s - loss: 0.0137 - mean_squared_error: 4.1544e-04 - val_loss: 0.0173 - val_mean_squared_error: 0.0013
#
# Epoch 00172: val_mean_squared_error did not improve from 0.00090
# Epoch 173/3000
#  - 2s - loss: 0.0135 - mean_squared_error: 4.1036e-04 - val_loss: 0.0172 - val_mean_squared_error: 0.0020
#
# Epoch 00173: val_mean_squared_error did not improve from 0.00090
# Epoch 174/3000
#  - 2s - loss: 0.0130 - mean_squared_error: 3.5028e-04 - val_loss: 0.0244 - val_mean_squared_error: 0.0038
#
# Epoch 00174: val_mean_squared_error did not improve from 0.00090
# Epoch 175/3000
#  - 2s - loss: 0.0136 - mean_squared_error: 4.0026e-04 - val_loss: 0.0256 - val_mean_squared_error: 0.0040
#
# Epoch 00175: val_mean_squared_error did not improve from 0.00090
# Epoch 176/3000
#  - 2s - loss: 0.0135 - mean_squared_error: 5.5743e-04 - val_loss: 0.0215 - val_mean_squared_error: 0.0028
#
# Epoch 00176: val_mean_squared_error did not improve from 0.00090
# Epoch 177/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.2952e-04 - val_loss: 0.0205 - val_mean_squared_error: 0.0031
#
# Epoch 00177: val_mean_squared_error did not improve from 0.00090
# Epoch 178/3000
#  - 2s - loss: 0.0131 - mean_squared_error: 3.2727e-04 - val_loss: 0.0219 - val_mean_squared_error: 0.0028
#
# Epoch 00178: val_mean_squared_error did not improve from 0.00090
# Epoch 179/3000
#  - 2s - loss: 0.0133 - mean_squared_error: 4.1338e-04 - val_loss: 0.0218 - val_mean_squared_error: 0.0024
#
# Epoch 00179: val_mean_squared_error did not improve from 0.00090
# Epoch 180/3000
#  - 2s - loss: 0.0123 - mean_squared_error: 3.6634e-04 - val_loss: 0.0187 - val_mean_squared_error: 0.0020
#
# Epoch 00180: val_mean_squared_error did not improve from 0.00090
# Epoch 181/3000
#  - 2s - loss: 0.0137 - mean_squared_error: 3.7184e-04 - val_loss: 0.0158 - val_mean_squared_error: 0.0010
#
# Epoch 00181: val_mean_squared_error did not improve from 0.00090
# Epoch 182/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 3.9877e-04 - val_loss: 0.0185 - val_mean_squared_error: 0.0026
#
# Epoch 00182: val_mean_squared_error did not improve from 0.00090
# Epoch 183/3000
#  - 2s - loss: 0.0139 - mean_squared_error: 4.9467e-04 - val_loss: 0.0211 - val_mean_squared_error: 0.0030
#
# Epoch 00183: val_mean_squared_error did not improve from 0.00090
# Epoch 184/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 3.9900e-04 - val_loss: 0.0253 - val_mean_squared_error: 0.0056
#
# Epoch 00184: val_mean_squared_error did not improve from 0.00090
# Epoch 185/3000
#  - 2s - loss: 0.0124 - mean_squared_error: 3.2354e-04 - val_loss: 0.0214 - val_mean_squared_error: 0.0036
#
# Epoch 00185: val_mean_squared_error did not improve from 0.00090
# Epoch 186/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.1620e-04 - val_loss: 0.0210 - val_mean_squared_error: 0.0024
#
# Epoch 00186: val_mean_squared_error did not improve from 0.00090
# Epoch 187/3000
#  - 2s - loss: 0.0137 - mean_squared_error: 4.1932e-04 - val_loss: 0.0211 - val_mean_squared_error: 0.0028
#
# Epoch 00187: val_mean_squared_error did not improve from 0.00090
# Epoch 188/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 4.3851e-04 - val_loss: 0.0160 - val_mean_squared_error: 0.0015
#
# Epoch 00188: val_mean_squared_error did not improve from 0.00090
# Epoch 189/3000
#  - 2s - loss: 0.0131 - mean_squared_error: 3.6830e-04 - val_loss: 0.0143 - val_mean_squared_error: 8.8771e-04
#
# Epoch 00189: val_mean_squared_error improved from 0.00090 to 0.00089, saving model to weights.best1.hdf5
# Epoch 190/3000
#  - 2s - loss: 0.0128 - mean_squared_error: 3.1642e-04 - val_loss: 0.0130 - val_mean_squared_error: 8.2508e-04
#
# Epoch 00190: val_mean_squared_error improved from 0.00089 to 0.00083, saving model to weights.best1.hdf5
# Epoch 191/3000
#  - 2s - loss: 0.0123 - mean_squared_error: 3.1879e-04 - val_loss: 0.0150 - val_mean_squared_error: 0.0012
#
# Epoch 00191: val_mean_squared_error did not improve from 0.00083
# Epoch 192/3000
#  - 2s - loss: 0.0116 - mean_squared_error: 2.6843e-04 - val_loss: 0.0159 - val_mean_squared_error: 0.0015
#
# Epoch 00192: val_mean_squared_error did not improve from 0.00083
# Epoch 193/3000
#  - 2s - loss: 0.0128 - mean_squared_error: 3.3994e-04 - val_loss: 0.0134 - val_mean_squared_error: 6.5853e-04
#
# Epoch 00193: val_mean_squared_error improved from 0.00083 to 0.00066, saving model to weights.best1.hdf5
# Epoch 194/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 4.3836e-04 - val_loss: 0.0191 - val_mean_squared_error: 0.0024
#
# Epoch 00194: val_mean_squared_error did not improve from 0.00066
# Epoch 195/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 4.6027e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0020
#
# Epoch 00195: val_mean_squared_error did not improve from 0.00066
# Epoch 196/3000
#  - 2s - loss: 0.0136 - mean_squared_error: 3.7032e-04 - val_loss: 0.0170 - val_mean_squared_error: 0.0012
#
# Epoch 00196: val_mean_squared_error did not improve from 0.00066
# Epoch 197/3000
#  - 2s - loss: 0.0140 - mean_squared_error: 3.8734e-04 - val_loss: 0.0188 - val_mean_squared_error: 0.0021
#
# Epoch 00197: val_mean_squared_error did not improve from 0.00066
# Epoch 198/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.4713e-04 - val_loss: 0.0152 - val_mean_squared_error: 0.0010
#
# Epoch 00198: val_mean_squared_error did not improve from 0.00066
# Epoch 199/3000
#  - 2s - loss: 0.0130 - mean_squared_error: 4.1265e-04 - val_loss: 0.0161 - val_mean_squared_error: 0.0013
#
# Epoch 00199: val_mean_squared_error did not improve from 0.00066
# Epoch 200/3000
#  - 2s - loss: 0.0131 - mean_squared_error: 4.2335e-04 - val_loss: 0.0238 - val_mean_squared_error: 0.0020
#
# Epoch 00200: val_mean_squared_error did not improve from 0.00066
# Epoch 201/3000
#  - 2s - loss: 0.0131 - mean_squared_error: 4.9427e-04 - val_loss: 0.0192 - val_mean_squared_error: 0.0022
#
# Epoch 00201: val_mean_squared_error did not improve from 0.00066
# Epoch 202/3000
#  - 2s - loss: 0.0124 - mean_squared_error: 3.3060e-04 - val_loss: 0.0150 - val_mean_squared_error: 0.0010
#
# Epoch 00202: val_mean_squared_error did not improve from 0.00066
# Epoch 203/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.6479e-04 - val_loss: 0.0183 - val_mean_squared_error: 0.0022
#
# Epoch 00203: val_mean_squared_error did not improve from 0.00066
# Epoch 204/3000
#  - 2s - loss: 0.0128 - mean_squared_error: 4.0395e-04 - val_loss: 0.0171 - val_mean_squared_error: 0.0015
#
# Epoch 00204: val_mean_squared_error did not improve from 0.00066
# Epoch 205/3000
#  - 2s - loss: 0.0131 - mean_squared_error: 4.4312e-04 - val_loss: 0.0190 - val_mean_squared_error: 0.0026
#
# Epoch 00205: val_mean_squared_error did not improve from 0.00066
# Epoch 206/3000
#  - 2s - loss: 0.0127 - mean_squared_error: 3.7134e-04 - val_loss: 0.0203 - val_mean_squared_error: 0.0019
#
# Epoch 00206: val_mean_squared_error did not improve from 0.00066
# Epoch 207/3000
#  - 2s - loss: 0.0137 - mean_squared_error: 3.8951e-04 - val_loss: 0.0190 - val_mean_squared_error: 9.1653e-04
#
# Epoch 00207: val_mean_squared_error did not improve from 0.00066
# Epoch 208/3000
#  - 2s - loss: 0.0142 - mean_squared_error: 4.7097e-04 - val_loss: 0.0267 - val_mean_squared_error: 0.0032
#
# Epoch 00208: val_mean_squared_error did not improve from 0.00066
# Epoch 209/3000
#  - 2s - loss: 0.0149 - mean_squared_error: 4.7534e-04 - val_loss: 0.0197 - val_mean_squared_error: 0.0011
#
# Epoch 00209: val_mean_squared_error did not improve from 0.00066
# Epoch 210/3000
#  - 2s - loss: 0.0132 - mean_squared_error: 3.4837e-04 - val_loss: 0.0160 - val_mean_squared_error: 0.0012
#
# Epoch 00210: val_mean_squared_error did not improve from 0.00066
# Epoch 211/3000
#  - 2s - loss: 0.0128 - mean_squared_error: 4.8472e-04 - val_loss: 0.0181 - val_mean_squared_error: 0.0016
#
# Epoch 00211: val_mean_squared_error did not improve from 0.00066
# Epoch 212/3000
#  - 2s - loss: 0.0181 - mean_squared_error: 0.0014 - val_loss: 0.0239 - val_mean_squared_error: 0.0037
#
# Epoch 00212: val_mean_squared_error did not improve from 0.00066
# Epoch 213/3000
#  - 2s - loss: 0.0159 - mean_squared_error: 8.4832e-04 - val_loss: 0.0213 - val_mean_squared_error: 0.0022
#
# Epoch 00213: val_mean_squared_error did not improve from 0.00066
# Epoch 214/3000
#  - 2s - loss: 0.0150 - mean_squared_error: 6.3134e-04 - val_loss: 0.0198 - val_mean_squared_error: 0.0024
#
# Epoch 00214: val_mean_squared_error did not improve from 0.00066
# Epoch 215/3000
#  - 2s - loss: 0.0148 - mean_squared_error: 6.5064e-04 - val_loss: 0.0191 - val_mean_squared_error: 0.0020
#
# Epoch 00215: val_mean_squared_error did not improve from 0.00066
# Epoch 216/3000
#  - 2s - loss: 0.0133 - mean_squared_error: 3.9714e-04 - val_loss: 0.0279 - val_mean_squared_error: 0.0043
#
# Epoch 00216: val_mean_squared_error did not improve from 0.00066
# Epoch 217/3000
#  - 2s - loss: 0.0199 - mean_squared_error: 0.0023 - val_loss: 0.0268 - val_mean_squared_error: 0.0039
#
# Epoch 00217: val_mean_squared_error did not improve from 0.00066
# Epoch 218/3000
#  - 2s - loss: 0.0199 - mean_squared_error: 0.0020 - val_loss: 0.0278 - val_mean_squared_error: 0.0044
#
# Epoch 00218: val_mean_squared_error did not improve from 0.00066
# Epoch 219/3000
#  - 2s - loss: 0.0170 - mean_squared_error: 0.0011 - val_loss: 0.0389 - val_mean_squared_error: 0.0070
#
# Epoch 00219: val_mean_squared_error did not improve from 0.00066
# Epoch 220/3000
#  - 2s - loss: 0.0157 - mean_squared_error: 9.1913e-04 - val_loss: 0.0198 - val_mean_squared_error: 0.0022
#
# Epoch 00220: val_mean_squared_error did not improve from 0.00066
# Epoch 221/3000
#  - 2s - loss: 0.0140 - mean_squared_error: 5.0430e-04 - val_loss: 0.0188 - val_mean_squared_error: 0.0027
#
# Epoch 00221: val_mean_squared_error did not improve from 0.00066
# Epoch 222/3000
#  - 2s - loss: 0.0143 - mean_squared_error: 5.9287e-04 - val_loss: 0.0215 - val_mean_squared_error: 0.0031
#
# Epoch 00222: val_mean_squared_error did not improve from 0.00066
# Epoch 223/3000
#  - 2s - loss: 0.0140 - mean_squared_error: 5.7918e-04 - val_loss: 0.0284 - val_mean_squared_error: 0.0047
#
# Epoch 00223: val_mean_squared_error did not improve from 0.00066
# Epoch 224/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 5.0460e-04 - val_loss: 0.0232 - val_mean_squared_error: 0.0037
#
# Epoch 00224: val_mean_squared_error did not improve from 0.00066
# Epoch 225/3000
#  - 2s - loss: 0.0135 - mean_squared_error: 5.8954e-04 - val_loss: 0.0241 - val_mean_squared_error: 0.0041
#
# Epoch 00225: val_mean_squared_error did not improve from 0.00066
# Epoch 226/3000
#  - 2s - loss: 0.0128 - mean_squared_error: 4.0305e-04 - val_loss: 0.0235 - val_mean_squared_error: 0.0032
#
# Epoch 00226: val_mean_squared_error did not improve from 0.00066
# Epoch 227/3000
#  - 2s - loss: 0.0129 - mean_squared_error: 3.6122e-04 - val_loss: 0.0225 - val_mean_squared_error: 0.0032
#
# Epoch 00227: val_mean_squared_error did not improve from 0.00066
# Epoch 228/3000
#  - 2s - loss: 0.0138 - mean_squared_error: 5.9625e-04 - val_loss: 0.0323 - val_mean_squared_error: 0.0050
#
# Epoch 00228: val_mean_squared_error did not improve from 0.00066
# Epoch 229/3000
#  - 2s - loss: 0.0248 - mean_squared_error: 0.0030 - val_loss: 0.0255 - val_mean_squared_error: 0.0041
#
# Epoch 00229: val_mean_squared_error did not improve from 0.00066
# Epoch 230/3000
#  - 2s - loss: 0.0237 - mean_squared_error: 0.0030 - val_loss: 0.0239 - val_mean_squared_error: 0.0039
#
# Epoch 00230: val_mean_squared_error did not improve from 0.00066
# Epoch 231/3000
#  - 2s - loss: 0.0176 - mean_squared_error: 0.0011 - val_loss: 0.0219 - val_mean_squared_error: 0.0027
#
# Epoch 00231: val_mean_squared_error did not improve from 0.00066
# Epoch 232/3000
#  - 2s - loss: 0.0152 - mean_squared_error: 6.6791e-04 - val_loss: 0.0227 - val_mean_squared_error: 0.0022
#
# Epoch 00232: val_mean_squared_error did not improve from 0.00066
# Epoch 233/3000
#  - 2s - loss: 0.0146 - mean_squared_error: 5.8692e-04 - val_loss: 0.0218 - val_mean_squared_error: 0.0019
#
# Epoch 00233: val_mean_squared_error did not improve from 0.00066
# Epoch 234/3000
#  - 2s - loss: 0.0151 - mean_squared_error: 6.2810e-04 - val_loss: 0.0330 - val_mean_squared_error: 0.0059
#
# Epoch 00234: val_mean_squared_error did not improve from 0.00066
# Epoch 235/3000
#  - 2s - loss: 0.0141 - mean_squared_error: 5.6456e-04 - val_loss: 0.0182 - val_mean_squared_error: 0.0019
#
# Epoch 00235: val_mean_squared_error did not improve from 0.00066
# Epoch 236/3000
#  - 2s - loss: 0.0156 - mean_squared_error: 9.7676e-04 - val_loss: 0.0329 - val_mean_squared_error: 0.0057
#
# Epoch 00236: val_mean_squared_error did not improve from 0.00066
# Epoch 237/3000
#  - 2s - loss: 0.0164 - mean_squared_error: 0.0011 - val_loss: 0.0234 - val_mean_squared_error: 0.0029
#
# Epoch 00237: val_mean_squared_error did not improve from 0.00066
# Epoch 238/3000
#  - 2s - loss: 0.0157 - mean_squared_error: 8.0440e-04 - val_loss: 0.0178 - val_mean_squared_error: 0.0019
#
# Epoch 00238: val_mean_squared_error did not improve from 0.00066
# Epoch 239/3000
#  - 2s - loss: 0.0147 - mean_squared_error: 5.8990e-04 - val_loss: 0.0194 - val_mean_squared_error: 0.0027
#
# Epoch 00239: val_mean_squared_error did not improve from 0.00066
# Epoch 240/3000
#  - 2s - loss: 0.0156 - mean_squared_error: 9.7987e-04 - val_loss: 0.0246 - val_mean_squared_error: 0.0040
#
# Epoch 00240: val_mean_squared_error did not improve from 0.00066
# Epoch 241/3000
#  - 2s - loss: 0.0450 - mean_squared_error: 0.0090 - val_loss: 0.0980 - val_mean_squared_error: 0.0263
#
# Epoch 00241: val_mean_squared_error did not improve from 0.00066
# Epoch 242/3000
#  - 2s - loss: 0.0382 - mean_squared_error: 0.0069 - val_loss: 0.0874 - val_mean_squared_error: 0.0260
#
# Epoch 00242: val_mean_squared_error did not improve from 0.00066
# Epoch 243/3000
#  - 2s - loss: 0.0294 - mean_squared_error: 0.0039 - val_loss: 0.0353 - val_mean_squared_error: 0.0070
#
# Epoch 00243: val_mean_squared_error did not improve from 0.00066
# Epoch 244/3000
#  - 2s - loss: 0.0236 - mean_squared_error: 0.0025 - val_loss: 0.0492 - val_mean_squared_error: 0.0123
#
# Epoch 00244: val_mean_squared_error did not improve from 0.00066
# Epoch 245/3000
#  - 2s - loss: 0.0223 - mean_squared_error: 0.0026 - val_loss: 0.0505 - val_mean_squared_error: 0.0129
#
# Epoch 00245: val_mean_squared_error did not improve from 0.00066
# Epoch 246/3000
#  - 2s - loss: 0.0211 - mean_squared_error: 0.0021 - val_loss: 0.0292 - val_mean_squared_error: 0.0053
#
# Epoch 00246: val_mean_squared_error did not improve from 0.00066
# Epoch 247/3000
#  - 2s - loss: 0.0200 - mean_squared_error: 0.0019 - val_loss: 0.0290 - val_mean_squared_error: 0.0051
#
# Epoch 00247: val_mean_squared_error did not improve from 0.00066
# Epoch 248/3000
#  - 2s - loss: 0.0179 - mean_squared_error: 0.0013 - val_loss: 0.0215 - val_mean_squared_error: 0.0022
#
# Epoch 00248: val_mean_squared_error did not improve from 0.00066
# Epoch 249/3000
#  - 2s - loss: 0.0157 - mean_squared_error: 7.6302e-04 - val_loss: 0.0219 - val_mean_squared_error: 0.0027
#
# Epoch 00249: val_mean_squared_error did not improve from 0.00066
# Epoch 250/3000
#  - 2s - loss: 0.0153 - mean_squared_error: 7.1164e-04 - val_loss: 0.0216 - val_mean_squared_error: 0.0022
#
# Epoch 00250: val_mean_squared_error did not improve from 0.00066
# Epoch 251/3000
#  - 2s - loss: 0.0162 - mean_squared_error: 7.5333e-04 - val_loss: 0.0229 - val_mean_squared_error: 0.0033
#
# Epoch 00251: val_mean_squared_error did not improve from 0.00066
# Epoch 252/3000
#  - 2s - loss: 0.0351 - mean_squared_error: 0.0059 - val_loss: 0.0461 - val_mean_squared_error: 0.0079
#
# Epoch 00252: val_mean_squared_error did not improve from 0.00066
# Epoch 253/3000
#  - 2s - loss: 0.0283 - mean_squared_error: 0.0038 - val_loss: 0.0690 - val_mean_squared_error: 0.0152
#
# Epoch 00253: val_mean_squared_error did not improve from 0.00066
# Epoch 254/3000
#  - 2s - loss: 0.0251 - mean_squared_error: 0.0029 - val_loss: 0.0492 - val_mean_squared_error: 0.0130
#
# Epoch 00254: val_mean_squared_error did not improve from 0.00066
# Epoch 255/3000
#  - 2s - loss: 0.0239 - mean_squared_error: 0.0032 - val_loss: 0.0323 - val_mean_squared_error: 0.0062
#
# ...
#
# Epoch 01011: val_mean_squared_error did not improve from 0.00041
# Epoch 1012/3000
#  - 2s - loss: 0.0217 - mean_squared_error: 0.0022 - val_loss: 0.0365 - val_mean_squared_error: 0.0074
#
# Epoch 01012: val_mean_squared_error did not improve from 0.00041
# Epoch 1013/3000
#  - 2s - loss: 0.0183 - mean_squared_error: 0.0018 - val_loss: 0.0309 - val_mean_squared_error: 0.0059
#
# Epoch 01013: val_mean_squared_error did not improve from 0.00041
# Epoch 1014/3000
#  - 2s - loss: 0.0141 - mean_squared_error: 9.2592e-04 - val_loss: 0.0260 - val_mean_squared_error: 0.0053
#
# Epoch 01014: val_mean_squared_error did not improve from 0.00041
# Epoch 1015/3000
#  - 2s - loss: 0.0134 - mean_squared_error: 0.0010 - val_loss: 0.0204 - val_mean_squared_error: 0.0034
#
# Epoch 01015: val_mean_squared_error did not improve from 0.00041
# Epoch 1016/3000
#  - 2s - loss: 0.0119 - mean_squared_error: 6.1729e-04 - val_loss: 0.0198 - val_mean_squared_error: 0.0036
#
# Epoch 01016: val_mean_squared_error did not improve from 0.00041
# Epoch 1017/3000
#  - 2s - loss: 0.0109 - mean_squared_error: 4.3093e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0030
#
# Epoch 01017: val_mean_squared_error did not improve from 0.00041
# Epoch 1018/3000
#  - 2s - loss: 0.0105 - mean_squared_error: 3.2611e-04 - val_loss: 0.0144 - val_mean_squared_error: 0.0020
#
# Epoch 01018: val_mean_squared_error did not improve from 0.00041
# Epoch 1019/3000
#  - 2s - loss: 0.0104 - mean_squared_error: 3.1367e-04 - val_loss: 0.0145 - val_mean_squared_error: 0.0021
#
# Epoch 01019: val_mean_squared_error did not improve from 0.00041
# Epoch 1020/3000
#  - 2s - loss: 0.0097 - mean_squared_error: 2.0064e-04 - val_loss: 0.0140 - val_mean_squared_error: 0.0018
#
# Epoch 01020: val_mean_squared_error did not improve from 0.00041
# Epoch 1021/3000
#  - 2s - loss: 0.0104 - mean_squared_error: 2.7225e-04 - val_loss: 0.0132 - val_mean_squared_error: 0.0019
#
# Epoch 01021: val_mean_squared_error did not improve from 0.00041
# Epoch 1022/3000
#  - 2s - loss: 0.0095 - mean_squared_error: 1.9014e-04 - val_loss: 0.0132 - val_mean_squared_error: 0.0018
#
# Epoch 01022: val_mean_squared_error did not improve from 0.00041
# Epoch 1023/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 1.6160e-04 - val_loss: 0.0144 - val_mean_squared_error: 0.0019
#
# Epoch 01023: val_mean_squared_error did not improve from 0.00041
# Epoch 1024/3000
#  - 2s - loss: 0.0098 - mean_squared_error: 2.1655e-04 - val_loss: 0.0141 - val_mean_squared_error: 0.0022
#
# Epoch 01024: val_mean_squared_error did not improve from 0.00041
# Epoch 1025/3000
#  - 2s - loss: 0.0096 - mean_squared_error: 2.5677e-04 - val_loss: 0.0131 - val_mean_squared_error: 0.0019
#
# Epoch 01025: val_mean_squared_error did not improve from 0.00041
# Epoch 1026/3000
#  - 2s - loss: 0.0093 - mean_squared_error: 1.7050e-04 - val_loss: 0.0126 - val_mean_squared_error: 0.0018
#
# Epoch 01026: val_mean_squared_error did not improve from 0.00041
# Epoch 1027/3000
#  - 2s - loss: 0.0095 - mean_squared_error: 1.9262e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0016
#
# Epoch 01027: val_mean_squared_error did not improve from 0.00041
# Epoch 1028/3000
#  - 2s - loss: 0.0094 - mean_squared_error: 3.3856e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0012
#
# Epoch 01028: val_mean_squared_error did not improve from 0.00041
# Epoch 1029/3000
#  - 2s - loss: 0.0096 - mean_squared_error: 2.4875e-04 - val_loss: 0.0135 - val_mean_squared_error: 0.0017
#
# Epoch 01029: val_mean_squared_error did not improve from 0.00041
# Epoch 1030/3000
#  - 2s - loss: 0.0097 - mean_squared_error: 2.0223e-04 - val_loss: 0.0130 - val_mean_squared_error: 0.0013
#
# Epoch 01030: val_mean_squared_error did not improve from 0.00041
# Epoch 1031/3000
#  - 2s - loss: 0.0094 - mean_squared_error: 1.8079e-04 - val_loss: 0.0125 - val_mean_squared_error: 0.0011
#
# Epoch 01031: val_mean_squared_error did not improve from 0.00041
# Epoch 1032/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.7223e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0016
#
# Epoch 01032: val_mean_squared_error did not improve from 0.00041
# Epoch 1033/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.8467e-04 - val_loss: 0.0117 - val_mean_squared_error: 0.0014
#
# Epoch 01033: val_mean_squared_error did not improve from 0.00041
# Epoch 1034/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 2.0442e-04 - val_loss: 0.0113 - val_mean_squared_error: 0.0011
#
# Epoch 01034: val_mean_squared_error did not improve from 0.00041
# Epoch 1035/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.7066e-04 - val_loss: 0.0117 - val_mean_squared_error: 0.0012
#
# Epoch 01035: val_mean_squared_error did not improve from 0.00041
# Epoch 1036/3000
#  - 2s - loss: 0.0092 - mean_squared_error: 1.8846e-04 - val_loss: 0.0108 - val_mean_squared_error: 8.4399e-04
#
# Epoch 01036: val_mean_squared_error did not improve from 0.00041
# Epoch 1037/3000
#  - 2s - loss: 0.0093 - mean_squared_error: 1.6337e-04 - val_loss: 0.0122 - val_mean_squared_error: 9.1935e-04
#
# Epoch 01037: val_mean_squared_error did not improve from 0.00041
# Epoch 1038/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.4693e-04 - val_loss: 0.0107 - val_mean_squared_error: 9.1401e-04
#
# Epoch 01038: val_mean_squared_error did not improve from 0.00041
# Epoch 1039/3000
#  - 2s - loss: 0.0094 - mean_squared_error: 1.7653e-04 - val_loss: 0.0113 - val_mean_squared_error: 9.8559e-04
#
# Epoch 01039: val_mean_squared_error did not improve from 0.00041
# Epoch 1040/3000
#  - 2s - loss: 0.0095 - mean_squared_error: 2.9239e-04 - val_loss: 0.0110 - val_mean_squared_error: 9.9070e-04
#
# Epoch 01040: val_mean_squared_error did not improve from 0.00041
# Epoch 1041/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 1.5785e-04 - val_loss: 0.0110 - val_mean_squared_error: 0.0011
#
# Epoch 01041: val_mean_squared_error did not improve from 0.00041
# Epoch 1042/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.5061e-04 - val_loss: 0.0116 - val_mean_squared_error: 0.0015
#
# Epoch 01042: val_mean_squared_error did not improve from 0.00041
# Epoch 1043/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 2.1992e-04 - val_loss: 0.0116 - val_mean_squared_error: 0.0017
#
# Epoch 01043: val_mean_squared_error did not improve from 0.00041
# Epoch 1044/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.6498e-04 - val_loss: 0.0122 - val_mean_squared_error: 0.0017
#
# Epoch 01044: val_mean_squared_error did not improve from 0.00041
# Epoch 1045/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.7338e-04 - val_loss: 0.0124 - val_mean_squared_error: 0.0017
#
# Epoch 01045: val_mean_squared_error did not improve from 0.00041
# Epoch 1046/3000
#  - 2s - loss: 0.0083 - mean_squared_error: 1.3346e-04 - val_loss: 0.0117 - val_mean_squared_error: 0.0018
#
# Epoch 01046: val_mean_squared_error did not improve from 0.00041
# Epoch 1047/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.5951e-04 - val_loss: 0.0116 - val_mean_squared_error: 0.0018
#
# Epoch 01047: val_mean_squared_error did not improve from 0.00041
# Epoch 1048/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.6243e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0017
#
# Epoch 01048: val_mean_squared_error did not improve from 0.00041
# Epoch 1049/3000
#  - 2s - loss: 0.0092 - mean_squared_error: 1.6017e-04 - val_loss: 0.0136 - val_mean_squared_error: 0.0017
#
# Epoch 01049: val_mean_squared_error did not improve from 0.00041
# Epoch 1050/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.4940e-04 - val_loss: 0.0109 - val_mean_squared_error: 0.0011
#
# Epoch 01050: val_mean_squared_error did not improve from 0.00041
# Epoch 1051/3000
#  - 2s - loss: 0.0085 - mean_squared_error: 1.5926e-04 - val_loss: 0.0113 - val_mean_squared_error: 0.0010
#
# Epoch 01051: val_mean_squared_error did not improve from 0.00041
# Epoch 1052/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.8482e-04 - val_loss: 0.0102 - val_mean_squared_error: 8.6645e-04
#
# Epoch 01052: val_mean_squared_error did not improve from 0.00041
# Epoch 1053/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.4535e-04 - val_loss: 0.0104 - val_mean_squared_error: 9.1550e-04
#
# Epoch 01053: val_mean_squared_error did not improve from 0.00041
# Epoch 1054/3000
#  - 2s - loss: 0.0084 - mean_squared_error: 1.3702e-04 - val_loss: 0.0108 - val_mean_squared_error: 0.0010
#
# Epoch 01054: val_mean_squared_error did not improve from 0.00041
# Epoch 1055/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.5046e-04 - val_loss: 0.0104 - val_mean_squared_error: 0.0010
#
# Epoch 01055: val_mean_squared_error did not improve from 0.00041
# Epoch 1056/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4986e-04 - val_loss: 0.0106 - val_mean_squared_error: 0.0011
#
# Epoch 01056: val_mean_squared_error did not improve from 0.00041
# Epoch 1057/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.9969e-04 - val_loss: 0.0107 - val_mean_squared_error: 0.0011
#
# Epoch 01057: val_mean_squared_error did not improve from 0.00041
# Epoch 1058/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 3.8611e-04 - val_loss: 0.0120 - val_mean_squared_error: 0.0016
#
# Epoch 01058: val_mean_squared_error did not improve from 0.00041
# Epoch 1059/3000
#  - 2s - loss: 0.0099 - mean_squared_error: 9.0037e-04 - val_loss: 0.0148 - val_mean_squared_error: 0.0022
#
# Epoch 01059: val_mean_squared_error did not improve from 0.00041
# Epoch 1060/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 1.8500e-04 - val_loss: 0.0137 - val_mean_squared_error: 0.0017
#
# Epoch 01060: val_mean_squared_error did not improve from 0.00041
# Epoch 1061/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.5946e-04 - val_loss: 0.0112 - val_mean_squared_error: 8.7643e-04
#
# Epoch 01061: val_mean_squared_error did not improve from 0.00041
# Epoch 1062/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.7042e-04 - val_loss: 0.0103 - val_mean_squared_error: 0.0010
#
# Epoch 01062: val_mean_squared_error did not improve from 0.00041
# Epoch 1063/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.6027e-04 - val_loss: 0.0105 - val_mean_squared_error: 9.9515e-04
#
# Epoch 01063: val_mean_squared_error did not improve from 0.00041
# Epoch 1064/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.8550e-04 - val_loss: 0.0102 - val_mean_squared_error: 8.5858e-04
#
# Epoch 01064: val_mean_squared_error did not improve from 0.00041
# Epoch 1065/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.5159e-04 - val_loss: 0.0100 - val_mean_squared_error: 8.5436e-04
#
# Epoch 01065: val_mean_squared_error did not improve from 0.00041
# Epoch 1066/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.6365e-04 - val_loss: 0.0103 - val_mean_squared_error: 8.5067e-04
#
# Epoch 01066: val_mean_squared_error did not improve from 0.00041
# Epoch 1067/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.4451e-04 - val_loss: 0.0104 - val_mean_squared_error: 9.1881e-04
#
# Epoch 01067: val_mean_squared_error did not improve from 0.00041
# Epoch 1068/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.7172e-04 - val_loss: 0.0112 - val_mean_squared_error: 0.0012
#
# Epoch 01068: val_mean_squared_error did not improve from 0.00041
# Epoch 1069/3000
#  - 2s - loss: 0.0089 - mean_squared_error: 1.7176e-04 - val_loss: 0.0101 - val_mean_squared_error: 0.0011
#
# Epoch 01069: val_mean_squared_error did not improve from 0.00041
# Epoch 1070/3000
#  - 2s - loss: 0.0084 - mean_squared_error: 1.3511e-04 - val_loss: 0.0113 - val_mean_squared_error: 0.0013
#
# Epoch 01070: val_mean_squared_error did not improve from 0.00041
# Epoch 1071/3000
#  - 2s - loss: 0.0087 - mean_squared_error: 1.4689e-04 - val_loss: 0.0106 - val_mean_squared_error: 0.0013
#
# Epoch 01071: val_mean_squared_error did not improve from 0.00041
# Epoch 1072/3000
#  - 2s - loss: 0.0083 - mean_squared_error: 1.3074e-04 - val_loss: 0.0101 - val_mean_squared_error: 0.0013
#
# Epoch 01072: val_mean_squared_error did not improve from 0.00041
# Epoch 1073/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.5948e-04 - val_loss: 0.0107 - val_mean_squared_error: 0.0012
#
# Epoch 01073: val_mean_squared_error did not improve from 0.00041
# Epoch 1074/3000
#  - 2s - loss: 0.0085 - mean_squared_error: 1.4768e-04 - val_loss: 0.0111 - val_mean_squared_error: 0.0014
#
# Epoch 01074: val_mean_squared_error did not improve from 0.00041
# Epoch 1075/3000
#  - 2s - loss: 0.0092 - mean_squared_error: 2.9697e-04 - val_loss: 0.0107 - val_mean_squared_error: 0.0012
#
# Epoch 01075: val_mean_squared_error did not improve from 0.00041
# Epoch 1076/3000
#  - 2s - loss: 0.0091 - mean_squared_error: 1.7060e-04 - val_loss: 0.0107 - val_mean_squared_error: 0.0013
#
# Epoch 01076: val_mean_squared_error did not improve from 0.00041
# Epoch 1077/3000
#  - 2s - loss: 0.0084 - mean_squared_error: 1.3742e-04 - val_loss: 0.0109 - val_mean_squared_error: 0.0014
#
# Epoch 01077: val_mean_squared_error did not improve from 0.00041
# Epoch 1078/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.4516e-04 - val_loss: 0.0113 - val_mean_squared_error: 0.0015
#
# Epoch 01078: val_mean_squared_error did not improve from 0.00041
# Epoch 1079/3000
#  - 2s - loss: 0.0084 - mean_squared_error: 1.4239e-04 - val_loss: 0.0110 - val_mean_squared_error: 0.0015
#
# Epoch 01079: val_mean_squared_error did not improve from 0.00041
# Epoch 1080/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.6592e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0018
#
# Epoch 01080: val_mean_squared_error did not improve from 0.00041
# Epoch 1081/3000
#  - 2s - loss: 0.0088 - mean_squared_error: 1.4970e-04 - val_loss: 0.0131 - val_mean_squared_error: 0.0018
#
# Epoch 01081: val_mean_squared_error did not improve from 0.00041
# Epoch 1082/3000
#  - 2s - loss: 0.0090 - mean_squared_error: 2.1095e-04 - val_loss: 0.0116 - val_mean_squared_error: 0.0018
#
# Epoch 01082: val_mean_squared_error did not improve from 0.00041
# Epoch 1083/3000
#  - 2s - loss: 0.0086 - mean_squared_error: 1.7893e-04 - val_loss: 0.0121 - val_mean_squared_error: 0.0020
#
# Epoch 01083: val_mean_squared_error did not improve from 0.00041
# Epoch 1084/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-24454acde79c> in <module>()
#       8     shuffle=True,
#       9     callbacks=callbacks_list,
# ---> 10     verbose=2)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
Y_pred = model.predict(X_test)
Y_test = Y_test * 150 + 50
Y_pred = Y_pred * 150 + 50
plt.figure
plt.scatter(Y_test, Y_pred)
Y_error = abs(Y_pred - Y_test)
print('The avarage predict error: ', np.mean(Y_error))
print('The mean squared error:', metrics.mean_squared_error(Y_test, Y_pred))
# Out:
# The avarage predict error:  1.83273939147
# The mean squared error: 43.2455275435

# %%
Y_pred = model.predict(X_train)
Y_train = Y_train * 150 + 50
Y_pred = Y_pred * 150 + 50
plt.figure
plt.scatter(Y_train, Y_pred)
Y_error = abs(Y_pred - Y_train)
print('The avarage predict error: ', np.mean(Y_error))
print('The mean squared error:', metrics.mean_squared_error(Y_train, Y_pred))
# Out:
# The avarage predict error:  0.75178415792
# The mean squared error: 10.9185966341

# %%
# Using the best model
model.load_weights("weights.best1.hdf5")

# %%
Y_pred = model.predict(X_test)
Y_pred = Y_pred * 150 + 50
plt.figure
plt.scatter(Y_test, Y_pred)
Y_error = abs(Y_pred - Y_test)
print('The avarage predict error: ', np.mean(Y_error))
print('The mean squared error:', metrics.mean_squared_error(Y_test, Y_pred))
# Out:
# The avarage predict error:  2.00730207563
# The mean squared error: 35.4226827876

# %%
Y_pred = model.predict(X_train)
#Y_train = Y_train * 150 + 50
Y_pred = Y_pred * 150 + 50
plt.figure
plt.scatter(Y_train, Y_pred)
Y_error = abs(Y_pred - Y_train)
print('The avarage predict error: ', np.mean(Y_error))
print('The mean squared error:', metrics.mean_squared_error(Y_train, Y_pred))
# Out:
# The avarage predict error:  0.939467304302
# The mean squared error: 2.84235428606
